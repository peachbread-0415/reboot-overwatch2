# %% [markdown]
# # Steam 멀티플레이어 게임 AppID 맵핑 및 최종 데이터 정제
#
# ## 조건
# - 데이터
#     1. 01-1. steam_data.csv : 크롤링·정제된 스팀 멀티플레이어 게임 목록 (한글 게임명 포함)
#     2. Steam_AppList.csv : Steam API(ISteamApps/GetAppList)에서 수집한 전체 앱 목록 (영문 게임명 포함)
# - 맵핑 기준
#     1. 1차: 게임명(영문 → 소문자 변환) 단순 매칭
#     2. 2차: 1차 매핑 실패 항목을 Steam 검색 페이지 크롤링을 통해 AppID 수집
#     3. 크롤링으로도 수집이 안 된 항목들은 갯수 확인하여 수동으로 수집하거나 삭제
# - 중복/부가상품 제거
#     1. DLC, 에디션, 번들, 사운드트랙, 코스튬, 키트, 특정 언어(일본어 타이틀) 등 제거
#     2. 부정확한 검색결과(특정 index) 수동 제거
# - 장르 필터
#     - 멀티플레이·슈팅·PvP·협동·MOBA·히어로 슈팅 등 오버워치와 같은 장르가 포함된 게임만 유지
# - 출력 데이터
#     - 최종 AppID 포함 CSV: 02-3. steam_data_real.csv
#
# ## 절차
# - Steam API 호출 → 전체 앱 목록 저장
# - 1차 맵핑
#     - 01-1. steam_data.csv와 Steam_AppList.csv를 게임명(소문자)기준으로 병합
#     <br> → 02-1. merged_steam_data.csv
# - 2차 맵핑(크롤링)
#     - 1차 매핑 실패 항목 리스트(recrawled) 생성
#     - Selenium + BeautifulSoup으로 Steam 스토어 검색 페이지 접근
#     - AppID 추출 규칙
#         - 일반 검색 결과에서 data-ds-appid 읽기
#         - 필터링 경고 페이지에서 링크의 /app/{appid}/ 패턴 추출
#     - 결과 저장: 02-2. mapped_appids_final.csv
# - AppID 재병합
#     - 1차 매핑 실패 항목에 2차 매핑 결과 병합
#     - 중복 제거 및 컬럼 재정렬 (appid, 게임명, 출시일, 장르, OS, DLC여부, 평가점수, 사용자 평가 수)
# - 데이터 정제
#     - 부가상품/불필요 항목 필터링
#         - "에디션", "번들", "코스튬", "키트", "soundtrack", "mode", "tracks", "패키지", "—", "–", "~" 등
#         - 일본어 타이틀, 불필요 index(drop list) 제거
#     - 장르 필터 적용: 멀티플레이·슈팅·MOBA·PvP·협동 등만 남김

# %% [markdown]
# ### 1. 전체 앱목록 저장

# %%
import requests
import pandas as pd

url = "https://api.steampowered.com/ISteamApps/GetAppList/v2/"
response = requests.get(url)
data = response.json()

apps = data["applist"]["apps"]

# DataFrame으로 변환
app_df = pd.DataFrame(apps)
print(app_df.head())  # 상위 5개만 보기

# 전체 저장도 가능
app_df.to_csv("Steam_AppList.csv", index=False, encoding="utf-8-sig")
# Out:
#    appid                   name
# 0      5       Dedicated Server
# 1      7           Steam Client
# 2      8                 winui2
# 3     10         Counter-Strike
# 4     20  Team Fortress Classic

# %% [markdown]
# ### 2. appID와 제목 맵핑

# %%
# appid 목록 (영문 제목 기준)
applist_df = pd.read_csv("Steam_AppList.csv")  # 컬럼: appid, name

# 장르 목록 (크롤링된 한글/영문 제목 기반)
multi_df = pd.read_csv("01. steam_data.csv")  # 컬럼: title_eng, genre 등

# 소문자 처리로 매칭률 높이기
applist_df['name'] = applist_df['name'].str.lower()
multi_df['게임명'] = multi_df['게임명'].str.lower()

# 단순 병합
merged_df = pd.merge(multi_df, applist_df, left_on='게임명', right_on='name', how='left')
merged_df.to_csv("02-1. merged_steam_data.csv", index=False, encoding="utf-8-sig")

# 매핑 성공/실패 확인
print("매핑 성공 수:", merged_df['appid'].notnull().sum())
print("매핑 실패 수:", merged_df['appid'].isnull().sum())

# 매핑 실패 항목 살펴보기
print(merged_df[merged_df['appid'].isnull()][['게임명']])
# Out:
# 매핑 성공 수: 21308
# 매핑 실패 수: 3287
#                       게임명
# 12                마법 주문 팀
# 14            the crew™ 2
# 17                오버워치™ 2
# 22     프로야구스피리츠 2024-2025
# 25        스노우 브레이크: 포비든 존
# ...                   ...
# 24533      crabs and rats
# 24560       adventure jam
# 24578  the train arrived!
# 24583    dispatch control
# 24591    watertrix online
#
# [3287 rows x 1 columns]

# %% [markdown]
# ### 3. 맵핑 실패 건 크롤링 후 재맵핑

# %%
recrawled = merged_df[merged_df['appid'].isnull()][['게임명']]

# %%
recrawled = recrawled['게임명'].tolist()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time
import re
import pandas as pd
import urllib.parse
from bs4 import BeautifulSoup

# === 1. Chrome 설정 ===
options = Options()
options.add_argument("--start-maximized")
options.add_experimental_option("detach", True)
driver = webdriver.Chrome(options=options)

# === 2. 검색 리스트 ===
recrawled 
title_list = []
appid_list = []

# === 3. 게임명 순회 ===
for title in recrawled:
    print(f"\n🔍 검색 중: {title}")
    encoded = urllib.parse.quote(title)
    url = f"https://store.steampowered.com/search/?term={encoded}&supportedlang=koreana&l=koreana"
    driver.get(url)
    time.sleep(2)

    soup = BeautifulSoup(driver.page_source, "html.parser")

    # 1순위: 일반 검색 결과
    result = soup.select_one("#search_resultsRows a.search_result_row")
    if result:
        appid = result.get("data-ds-appid")
        print(f"✅ 일반 결과: {title} → appid {appid}")
        appid_list.append(appid)
        title_list.append(title)
        continue

    # 2순위: 필터링된 결과에서 추출
    filtered_div = soup.select_one("#search_results_filtered_warning_persistent")
    if filtered_div:
        filtered_link = filtered_div.find("a", href=True)
        if filtered_link:
            href = filtered_link["href"]
            match = re.search(r'/app/(\d+)/', href)
            if match:
                appid = match.group(1)
                print(f"🔍 필터링 결과에서 추출됨 → appid {appid}")
                appid_list.append(appid)
                title_list.append(title)
                continue

    # 실패한 경우
    print("❌ appid 추출 실패")
    appid_list.append(None)
    title_list.append(title)

# === 4. 결과 저장 ===
appid_df = pd.DataFrame({
    "게임명": title_list,
    "appid": appid_list
})
appid_df.to_csv("02-2. mapped_appids_final.csv", index=False, encoding="utf-8-sig")
print("\n📁 저장 완료: 02-2. mapped_appids_final.csv")
# Out:
# 🔍 검색 중: 마법 주문 팀
# ✅ 일반 결과: 마법 주문 팀 → appid 2904000
#
# 🔍 검색 중: the crew™ 2
# ✅ 일반 결과: the crew™ 2 → appid 646910
#
# 🔍 검색 중: 오버워치™ 2
# ✅ 일반 결과: 오버워치™ 2 → appid 2357570
#
# 🔍 검색 중: 프로야구스피리츠 2024-2025
# 🔍 필터링 결과에서 추출됨 → appid 2051010
#
# 🔍 검색 중: 스노우 브레이크: 포비든 존
# ✅ 일반 결과: 스노우 브레이크: 포비든 존 → appid 2668080
#
# 🔍 검색 중: 소울워커
# ✅ 일반 결과: 소울워커 → appid 1825750
#
# 🔍 검색 중: ghost of tsushima 디렉터스 컷
# ✅ 일반 결과: ghost of tsushima 디렉터스 컷 → appid 2215430
#
# 🔍 검색 중: 인슈라오디드 (enshrouded)
# ✅ 일반 결과: 인슈라오디드 (enshrouded) → appid 1203620
#
# 🔍 검색 중: dune: awakening 듄 ：어웨이크닝
# ✅ 일반 결과: dune: awakening 듄 ：어웨이크닝 → appid 1172710
#
# 🔍 검색 중: 보더랜드 3
# ✅ 일반 결과: 보더랜드 3 → appid 397540
#
# 🔍 검색 중: tom clancy’s the division® 2
# ✅ 일반 결과: tom clancy’s the division® 2 → appid 2221490
#
# 🔍 검색 중: 방 탈출 시뮬레이터
# ✅ 일반 결과: 방 탈출 시뮬레이터 → appid 1435790
#
# 🔍 검색 중: liftoff®: fpv drone racing
# ✅ 일반 결과: liftoff®: fpv drone racing → appid 1301060
#
# 🔍 검색 중: operation: tango
# ✅ 일반 결과: operation: tango → appid 1335790
#
# 🔍 검색 중: far cry® 6
# ✅ 일반 결과: far cry® 6 → appid 2369390
#
# 🔍 검색 중: 루마섬
# ✅ 일반 결과: 루마섬 → appid 2408820
#
# 🔍 검색 중: 철권 8 파캄람
# ✅ 일반 결과: 철권 8 파캄람 → appid 3564540
#
# 🔍 검색 중: 텍사스 홀덤 포커: pokerist
# ✅ 일반 결과: 텍사스 홀덤 포커: pokerist → appid 3174070
#
# 🔍 검색 중: stronghold crusader: definitive edition 스트롱홀드 크루세이더: 결정판
# ✅ 일반 결과: stronghold crusader: definitive edition 스트롱홀드 크루세이더: 결정판 → appid 3024040
#
# 🔍 검색 중: call of duty®: wwii
# ✅ 일반 결과: call of duty®: wwii → appid 476600
#
# 🔍 검색 중: 플래닛 코스터 2
# ✅ 일반 결과: 플래닛 코스터 2 → appid 2688950
#
# 🔍 검색 중: sea of thieves: 2025 edition
# ✅ 일반 결과: sea of thieves: 2025 edition → appid 1172620
#
# 🔍 검색 중: mlb 라이벌
# ✅ 일반 결과: mlb 라이벌 → appid 2569510
#
# 🔍 검색 중: 진격의거인２
# ✅ 일반 결과: 진격의거인２ → appid 601050
#
# 🔍 검색 중: 토탈워: 워해머 3
# ✅ 일반 결과: 토탈워: 워해머 3 → appid 1142710
#
# 🔍 검색 중: astral party
# ✅ 일반 결과: astral party → appid 1149440
#
# 🔍 검색 중: 토탈워: 삼국
# ✅ 일반 결과: 토탈워: 삼국 → appid 779340
#
# 🔍 검색 중: 팝유컴
# ✅ 일반 결과: 팝유컴 → appid 2543180
#
# 🔍 검색 중: 레고® 2k 드라이브
# ✅ 일반 결과: 레고® 2k 드라이브 → appid 1451810
#
# 🔍 검색 중: 플레이투게더
# ✅ 일반 결과: 플레이투게더 → appid 3198850
#
# 🔍 검색 중: 진・삼국무쌍７ with 맹장전
# 🔍 필터링 결과에서 추출됨 → appid 278080
#
# 🔍 검색 중: naruto -나루토- 질풍전 나루티밋 스톰 4
# ✅ 일반 결과: naruto -나루토- 질풍전 나루티밋 스톰 4 → appid 349040
#
# 🔍 검색 중: 기동전사 건담 배틀 오퍼레이션 2
# ✅ 일반 결과: 기동전사 건담 배틀 오퍼레이션 2 → appid 1367080
#
# 🔍 검색 중: 하우스 플리퍼 2
# ✅ 일반 결과: 하우스 플리퍼 2 → appid 1190970
#
# 🔍 검색 중: 옛날 재래시장 시뮬레이터
# ✅ 일반 결과: 옛날 재래시장 시뮬레이터 → appid 2878420
#
# 🔍 검색 중: sky 빛의 아이들
# ✅ 일반 결과: sky 빛의 아이들 → appid 2325290
#
# 🔍 검색 중: 데스티니 가디언즈: 운명의 경계
# ✅ 일반 결과: 데스티니 가디언즈: 운명의 경계 → appid 3186490
#
# 🔍 검색 중: 열혈경파 쿠니오군 외전 리버시티 걸즈 2
# ✅ 일반 결과: 열혈경파 쿠니오군 외전 리버시티 걸즈 2 → appid 1920480
#
# 🔍 검색 중: necesse: 네세스
# ✅ 일반 결과: necesse: 네세스 → appid 1169040
#
# 🔍 검색 중: 스컬 앤 본즈
# ✅ 일반 결과: 스컬 앤 본즈 → appid 2853730
#
# 🔍 검색 중: 귀귀살전
# ✅ 일반 결과: 귀귀살전 → appid 2891940
#
# 🔍 검색 중: tom clancy's ghost recon® breakpoint
# ✅ 일반 결과: tom clancy's ghost recon® breakpoint → appid 2231380
#
# 🔍 검색 중: 星之翼
# ✅ 일반 결과: 星之翼 → appid 2764370
#
# 🔍 검색 중: microsoft flight simulator (2020) 40th anniversary edition
# 🔍 필터링 결과에서 추출됨 → appid 1250410
#
# 🔍 검색 중: 콜 오브 듀티®: 워존
# ✅ 일반 결과: 콜 오브 듀티®: 워존 → appid 1962663
#
# 🔍 검색 중: rival stars horse racing: desktop edition
# ✅ 일반 결과: rival stars horse racing: desktop edition → appid 1166860
#
# 🔍 검색 중: 리틀 나이트메어 3
# ✅ 일반 결과: 리틀 나이트메어 3 → appid 1392860
#
# 🔍 검색 중: assassin's creed® unity
# ✅ 일반 결과: assassin's creed® unity → appid 289650
#
# 🔍 검색 중: 반지의 제왕: 모리아로의 귀환™
# ✅ 일반 결과: 반지의 제왕: 모리아로의 귀환™ → appid 2933130
#
# 🔍 검색 중: ranch simulator: build, hunt, farm
# ✅ 일반 결과: ranch simulator: build, hunt, farm → appid 1119730
#
# 🔍 검색 중: 진・삼국무쌍８
# ✅ 일반 결과: 진・삼국무쌍８ → appid 1341200
#
# 🔍 검색 중: deadzone: rogue
# ✅ 일반 결과: deadzone: rogue → appid 3228590
#
# 🔍 검색 중: avatar: frontiers of pandora™
# ✅ 일반 결과: avatar: frontiers of pandora™ → appid 2840770
#
# 🔍 검색 중: 토탈워: 워해머 2
# ✅ 일반 결과: 토탈워: 워해머 2 → appid 594570
#
# 🔍 검색 중: 샵 타이탄
# ✅ 일반 결과: 샵 타이탄 → appid 1258080
#
# 🔍 검색 중: 주차도 못하네®
# ✅ 일반 결과: 주차도 못하네® → appid 837880
#
# 🔍 검색 중: battlefield 4™
# ✅ 일반 결과: battlefield 4™ → appid 1238860
#
# 🔍 검색 중: 다키스트 데이즈
# ✅ 일반 결과: 다키스트 데이즈 → appid 1548520
#
# 🔍 검색 중: 리듬 닥터 (rhythm doctor)
# ✅ 일반 결과: 리듬 닥터 (rhythm doctor) → appid 774181
#
# 🔍 검색 중: 콜 오브 듀티®
# ✅ 일반 결과: 콜 오브 듀티® → appid 1938090
#
# 🔍 검색 중: 아수라장
# ✅ 일반 결과: 아수라장 → appid 2549130
#
# 🔍 검색 중: sid meier’s civilization® vi: rise and fall
# ✅ 일반 결과: sid meier’s civilization® vi: rise and fall → appid 645402
#
# 🔍 검색 중: battlefield 3™
# ✅ 일반 결과: battlefield 3™ → appid 1238820
#
# 🔍 검색 중: icarus 외계 행성 서바이벌
# ✅ 일반 결과: icarus 외계 행성 서바이벌 → appid 1149460
#
# 🔍 검색 중: dying light 2 stay human: reloaded edition
# ✅ 일반 결과: dying light 2 stay human: reloaded edition → appid 534380
#
# 🔍 검색 중: ark: aquatica
# ✅ 일반 결과: ark: aquatica → appid 3537070
#
# 🔍 검색 중: 소녀와영주
# ✅ 일반 결과: 소녀와영주 → appid 3473160
#
# 🔍 검색 중: 드래곤볼 스파킹! 제로
# ✅ 일반 결과: 드래곤볼 스파킹! 제로 → appid 1790600
#
# 🔍 검색 중: 아포칼립스 파티
# ✅ 일반 결과: 아포칼립스 파티 → appid 2351560
#
# 🔍 검색 중: 둠스 헤어 살롱
# ✅ 일반 결과: 둠스 헤어 살롱 → appid 3398870
#
# 🔍 검색 중: 이프선셋
# ✅ 일반 결과: 이프선셋 → appid 2271930
#
# 🔍 검색 중: unrailed 2: back on track (언레일드 2: 백 온 트랙)
# ✅ 일반 결과: unrailed 2: back on track (언레일드 2: 백 온 트랙) → appid 2211170
#
# 🔍 검색 중: call of duty®: black ops 6
# ✅ 일반 결과: call of duty®: black ops 6 → appid 2933620
#
# 🔍 검색 중: 토탈워: 워해머
# ✅ 일반 결과: 토탈워: 워해머 → appid 1142710
#
# 🔍 검색 중: the elder scrolls® online
# ✅ 일반 결과: the elder scrolls® online → appid 460760
#
# 🔍 검색 중: 스매시 레전드
# ✅ 일반 결과: 스매시 레전드 → appid 1352080
#
# 🔍 검색 중: 아머드 코어 vi 루비콘의 화염
# ✅ 일반 결과: 아머드 코어 vi 루비콘의 화염 → appid 1888160
#
# 🔍 검색 중: 그레이 존 워페어
# ✅ 일반 결과: 그레이 존 워페어 → appid 2479810
#
# 🔍 검색 중: 인피니티 니키
# ✅ 일반 결과: 인피니티 니키 → appid 3164330
#
# 🔍 검색 중: far cry® 5
# ✅ 일반 결과: far cry® 5 → appid 552520
#
# 🔍 검색 중: 최후의 돌격
# ✅ 일반 결과: 최후의 돌격 → appid 2841770
#
# 🔍 검색 중: 5분레이드
# ✅ 일반 결과: 5분레이드 → appid 2936130
#
# 🔍 검색 중: 빼앗긴 왕국
# ✅ 일반 결과: 빼앗긴 왕국 → appid 1330000
#
# 🔍 검색 중: 팀파이트 매니저
# ✅ 일반 결과: 팀파이트 매니저 → appid 1372810
#
# 🔍 검색 중: daemon x machina titanic scion
# ✅ 일반 결과: daemon x machina titanic scion → appid 1342490
#
# 🔍 검색 중: company of heroes
# ✅ 일반 결과: company of heroes → appid 228200
#
# 🔍 검색 중: 소드 아트 온라인 라스트 리콜렉션
# ✅ 일반 결과: 소드 아트 온라인 라스트 리콜렉션 → appid 1566880
#
# 🔍 검색 중: 드래곤볼 더 브레이커즈
# ✅ 일반 결과: 드래곤볼 더 브레이커즈 → appid 1276760
#
# 🔍 검색 중: outward definitive edition
# ✅ 일반 결과: outward definitive edition → appid 794260
#
# 🔍 검색 중: 건담 브레이커 4
# ✅ 일반 결과: 건담 브레이커 4 → appid 1672500
#
# 🔍 검색 중: biohazard re:3
# ✅ 일반 결과: biohazard re:3 → appid 952060
#
# 🔍 검색 중: 태고의 달인 쿵딱! 원더풀 페스티벌
# ✅ 일반 결과: 태고의 달인 쿵딱! 원더풀 페스티벌 → appid 2288630
#
# 🔍 검색 중: 플레이트업!
# ✅ 일반 결과: 플레이트업! → appid 1599600
#
# 🔍 검색 중: 다른 겨울의 우리들
# ✅ 일반 결과: 다른 겨울의 우리들 → appid 1801110
#
# 🔍 검색 중: super mega baseball™ 4
# ✅ 일반 결과: super mega baseball™ 4 → appid 2305830
#
# 🔍 검색 중: sd건담 배틀 얼라이언스
# ✅ 일반 결과: sd건담 배틀 얼라이언스 → appid 824550
#
# 🔍 검색 중: 마블스냅
# ✅ 일반 결과: 마블스냅 → appid 1997040
#
# 🔍 검색 중: 아스팔트 레전드
# ✅ 일반 결과: 아스팔트 레전드 → appid 1815780
#
# 🔍 검색 중: 몬스터헌터 스토리즈 2 파멸의 날개
# ✅ 일반 결과: 몬스터헌터 스토리즈 2 파멸의 날개 → appid 1277400
#
# 🔍 검색 중: 데스티니 가디언즈: 재건 실버 번들
# ✅ 일반 결과: 데스티니 가디언즈: 재건 실버 번들 → appid 2972420
#
# 🔍 검색 중: once human-엘리트 일정 테마 패키지
# ✅ 일반 결과: once human-엘리트 일정 테마 패키지 → appid 3816110
#
# 🔍 검색 중: battle bundle – y9s2 – for honor
# ✅ 일반 결과: battle bundle – y9s2 – for honor → appid 3793390
#
# 🔍 검색 중: oddsparks: 자동화 모험
# ✅ 일반 결과: oddsparks: 자동화 모험 → appid None
#
# 🔍 검색 중: call of duty®: infinite warfare
# ✅ 일반 결과: call of duty®: infinite warfare → appid 292730
#
# 🔍 검색 중: 얼티밋 치킨 호스
# ✅ 일반 결과: 얼티밋 치킨 호스 → appid 386940
#
# 🔍 검색 중: 우당탕탕 경주 fling to the finish
# ✅ 일반 결과: 우당탕탕 경주 fling to the finish → appid 1054430
#
# 🔍 검색 중: 우리는 여기에 있었다 투게더
# ✅ 일반 결과: 우리는 여기에 있었다 투게더 → appid 865360
#
# 🔍 검색 중: 슈팅 스타 recharge
# ✅ 일반 결과: 슈팅 스타 recharge → appid 3225420
#
# 🔍 검색 중: 기름 캐자! 베프들
# ✅ 일반 결과: 기름 캐자! 베프들 → appid 3441460
#
# 🔍 검색 중: goddess of fate: waifu rpg
# ❌ appid 추출 실패
#
# 🔍 검색 중: 리스크 오브 레인 2: 폭풍의 탐구자
# ✅ 일반 결과: 리스크 오브 레인 2: 폭풍의 탐구자 → appid 2306620
#
# 🔍 검색 중: 콜 오브 듀티®: 모던 워페어 ii 2022
# ✅ 일반 결과: 콜 오브 듀티®: 모던 워페어 ii 2022 → appid 3595230
#
# 🔍 검색 중: 그리드랜드
# ✅ 일반 결과: 그리드랜드 → appid 2218400
#
# 🔍 검색 중: 백팩 배틀즈
# ✅ 일반 결과: 백팩 배틀즈 → appid 2427700
#
# 🔍 검색 중: 다른 별의 우리들
# ✅ 일반 결과: 다른 별의 우리들 → appid 3126150
#
# 🔍 검색 중: 귀멸의 칼날 히노카미 혈풍담
# ✅ 일반 결과: 귀멸의 칼날 히노카미 혈풍담 → appid 1490890
#
# 🔍 검색 중: ace combat™ 7: skies unknown
# ✅ 일반 결과: ace combat™ 7: skies unknown → appid 502500
#
# 🔍 검색 중: 용과 같이0 맹세의 장소
# ✅ 일반 결과: 용과 같이0 맹세의 장소 → appid None
#
# 🔍 검색 중: liftoff®: micro drones
# 🔍 필터링 결과에서 추출됨 → appid 1432320
#
# 🔍 검색 중: far cry® 4
# ✅ 일반 결과: far cry® 4 → appid 298110
#
# 🔍 검색 중: runescape ®
# ✅ 일반 결과: runescape ® → appid 1397370
#
# 🔍 검색 중: 원피스 해적무쌍 4
# ✅ 일반 결과: 원피스 해적무쌍 4 → appid 1089090
#
# 🔍 검색 중: the crucible lord – centurion hero skin – for honor
# ✅ 일반 결과: the crucible lord – centurion hero skin – for honor → appid 3255730
#
# 🔍 검색 중: 리벤지 오브 더 새비지 플레닛 / revenge of the savage planet
# ✅ 일반 결과: 리벤지 오브 더 새비지 플레닛 / revenge of the savage planet → appid 2787320
#
# 🔍 검색 중: scp: 5k
# ✅ 일반 결과: scp: 5k → appid 872670
#
# 🔍 검색 중: 矩阵：零日危机 / terminull brigade™
# ✅ 일반 결과: 矩阵：零日危机 / terminull brigade™ → appid 3104410
#
# 🔍 검색 중: 데스티니 가디언즈: 승리 실버 번들
# ✅ 일반 결과: 데스티니 가디언즈: 승리 실버 번들 → appid 1745440
#
# 🔍 검색 중: old world 올드 월드
# ✅ 일반 결과: old world 올드 월드 → appid 597180
#
# 🔍 검색 중: call of duty®: black ops
# ✅ 일반 결과: call of duty®: black ops → appid 2933620
#
# 🔍 검색 중: blood strike
# ✅ 일반 결과: blood strike → appid 2102730
#
# 🔍 검색 중: 迷宮校舎 | school labyrinth
# ✅ 일반 결과: 迷宮校舎 | school labyrinth → appid 2423300
#
# 🔍 검색 중: 블랙 스티그마
# ✅ 일반 결과: 블랙 스티그마 → appid 1277530
#
# 🔍 검색 중: 데스티니 가디언즈: 최후의 형체
# ✅ 일반 결과: 데스티니 가디언즈: 최후의 형체 → appid 2336880
#
# 🔍 검색 중: in sink: a co-op escape adventure
# ✅ 일반 결과: in sink: a co-op escape adventure → appid 1858650
#
# 🔍 검색 중: total war: napoleon – definitive edition
# ✅ 일반 결과: total war: napoleon – definitive edition → appid 1817361
#
# 🔍 검색 중: 모두의 골프 월드
# ✅ 일반 결과: 모두의 골프 월드 → appid 2730810
#
# 🔍 검색 중: 다함께 쿠키요미
# ✅ 일반 결과: 다함께 쿠키요미 → appid 1221540
#
# 🔍 검색 중: 귀멸의 칼날: 도전, 최강의 대원!
# ✅ 일반 결과: 귀멸의 칼날: 도전, 최강의 대원! → appid 2424110
#
# 🔍 검색 중: 뿌요뿌요™테트리스® 2
# ✅ 일반 결과: 뿌요뿌요™테트리스® 2 → appid 1259790
#
# 🔍 검색 중: navy war: 군함 온라인게임
# ✅ 일반 결과: navy war: 군함 온라인게임 → appid 1991850
#
# 🔍 검색 중: future gpx cyber formula sin vier
# 🔍 필터링 결과에서 추출됨 → appid 964230
#
# 🔍 검색 중: 얼티밋 좀비 디펜스 2
# ✅ 일반 결과: 얼티밋 좀비 디펜스 2 → appid 1765300
#
# 🔍 검색 중: rockman exe advanced collection vol.1
# 🔍 필터링 결과에서 추출됨 → appid 1798010
#
# 🔍 검색 중: the crew motorfest | year 2 pass
# ✅ 일반 결과: the crew motorfest | year 2 pass → appid 3251420
#
# 🔍 검색 중: nba 2k25 mycareer 보너스 혜택: 시즌 8
# ✅ 일반 결과: nba 2k25 mycareer 보너스 혜택: 시즌 8 → appid 3313040
#
# 🔍 검색 중: 슈퍼 테크노스 월드 ~열혈 & 아케이드 클래식 컬렉션~
# ✅ 일반 결과: 슈퍼 테크노스 월드 ~열혈 & 아케이드 클래식 컬렉션~ → appid None
#
# 🔍 검색 중: 별이되어라2: 베다의 기사들
# ✅ 일반 결과: 별이되어라2: 베다의 기사들 → appid 2484250
#
# 🔍 검색 중: 쿼리
# ✅ 일반 결과: 쿼리 → appid 1577120
#
# 🔍 검색 중: 열혈삼국지
# ✅ 일반 결과: 열혈삼국지 → appid 1013220
#
# 🔍 검색 중: watch_dogs™
# ✅ 일반 결과: watch_dogs™ → appid 447040
#
# 🔍 검색 중: 백룸 청소팀 (backrooms cleanup crew)
# ✅ 일반 결과: 백룸 청소팀 (backrooms cleanup crew) → appid 3140990
#
# 🔍 검색 중: 메탈슬러그: 각성
# ✅ 일반 결과: 메탈슬러그: 각성 → appid 2963870
#
# 🔍 검색 중: tom clancy’s ghost recon® breakpoint year 1 pass
# ✅ 일반 결과: tom clancy’s ghost recon® breakpoint year 1 pass → appid 2231410
#
# 🔍 검색 중: 게이트키퍼
# ✅ 일반 결과: 게이트키퍼 → appid 2106670
#
# 🔍 검색 중: mass effect™: andromeda 디럭스 에디션
# 🔍 필터링 결과에서 추출됨 → appid 1238000
#
# 🔍 검색 중: far cry 3
# ✅ 일반 결과: far cry 3 → appid 220240
#
# 🔍 검색 중: 바둑
# ✅ 일반 결과: 바둑 → appid 1862520
#
# 🔍 검색 중: bro falls
# ✅ 일반 결과: bro falls → appid 1590320
#
# 🔍 검색 중: 奇々怪界 黒マントの謎
# ✅ 일반 결과: 奇々怪界 黒マントの謎 → appid 2200580
#
# 🔍 검색 중: 마법소녀 카와이 러블리 즈큥도큥 바큥부큥 루루핑
# ✅ 일반 결과: 마법소녀 카와이 러블리 즈큥도큥 바큥부큥 루루핑 → appid 2696400
#
# 🔍 검색 중: 철권 8 pac-pixels
# ✅ 일반 결과: 철권 8 pac-pixels → appid 3564550
#
# 🔍 검색 중: oceanhorn: chronos dungeon (오션혼: 크로노스 던전)
# ✅ 일반 결과: oceanhorn: chronos dungeon (오션혼: 크로노스 던전) → appid 3025560
#
# 🔍 검색 중: 스타워즈: 스쿼드론
# ✅ 일반 결과: 스타워즈: 스쿼드론 → appid 1222730
#
# 🔍 검색 중: 스펙트럴 스크림
# ✅ 일반 결과: 스펙트럴 스크림 → appid 2620240
#
# 🔍 검색 중: 패들 패들 패들
# ✅ 일반 결과: 패들 패들 패들 → appid 3570070
#
# 🔍 검색 중: 오목 가자
# ✅ 일반 결과: 오목 가자 → appid 1555400
#
# 🔍 검색 중: <v rising>--'캐슬바니아의 유산' 클래식 패키지
# ✅ 일반 결과: <v rising>--'캐슬바니아의 유산' 클래식 패키지 → appid 2833600
#
# 🔍 검색 중: battlefield™ hardline 얼티밋 에디션
# ✅ 일반 결과: battlefield™ hardline 얼티밋 에디션 → appid 1238880
#
# 🔍 검색 중: 골밑 접전: 전술의 대가
# ✅ 일반 결과: 골밑 접전: 전술의 대가 → appid 2995450
#
# 🔍 검색 중: 데스티니 가디언즈: 빛의 추락
# ✅ 일반 결과: 데스티니 가디언즈: 빛의 추락 → appid 1945340
#
# 🔍 검색 중: 언디셈버
# ✅ 일반 결과: 언디셈버 → appid 1549250
#
# 🔍 검색 중: minecraft dungeons: 깨어난 정글
# ✅ 일반 결과: minecraft dungeons: 깨어난 정글 → appid 1672980
#
# 🔍 검색 중: age of empires iv: the sultans ascend
# ✅ 일반 결과: age of empires iv: the sultans ascend → appid 1959430
#
# 🔍 검색 중: truck & logistics simulator
# ✅ 일반 결과: truck & logistics simulator → appid 873840
#
# 🔍 검색 중: 철권 8 안나 윌리엄스
# ✅ 일반 결과: 철권 8 안나 윌리엄스 → appid 3417000
#
# 🔍 검색 중: 메카아라시
# ✅ 일반 결과: 메카아라시 → appid 3216320
#
# 🔍 검색 중: call of duty® 2
# ✅ 일반 결과: call of duty® 2 → appid 1938090
#
# 🔍 검색 중: call of duty® 4: modern warfare® (2007)
# ✅ 일반 결과: call of duty® 4: modern warfare® (2007) → appid None
#
# 🔍 검색 중: icarus: 신세계
# ✅ 일반 결과: icarus: 신세계 → appid 1648532
#
# 🔍 검색 중: 인과율
# ✅ 일반 결과: 인과율 → appid 1158720
#
# 🔍 검색 중: " 화의석 " 방치 영웅 rpg
# ✅ 일반 결과: " 화의석 " 방치 영웅 rpg → appid 1013320
#
# 🔍 검색 중: remnant ii®
# ✅ 일반 결과: remnant ii® → appid 1282100
#
# 🔍 검색 중: 당신의 어머니
# ✅ 일반 결과: 당신의 어머니 → appid 3399950
#
# 🔍 검색 중: 트리플 판타지
# ✅ 일반 결과: 트리플 판타지 → appid 1933450
#
# 🔍 검색 중: shop simulator: supermarket
# ✅ 일반 결과: shop simulator: supermarket → appid 2886550
#
# 🔍 검색 중: total war: empire – definitive edition
# ✅ 일반 결과: total war: empire – definitive edition → appid 594570
#
# 🔍 검색 중: 탑스핀 2k25
# ✅ 일반 결과: 탑스핀 2k25 → appid 1785650
#
# 🔍 검색 중: 퍼피 구조대: 그랑프리
# ✅ 일반 결과: 퍼피 구조대: 그랑프리 → appid 1770490
#
# 🔍 검색 중: legacy pass – y5s2 – for honor
# ✅ 일반 결과: legacy pass – y5s2 – for honor → appid 3793410
#
# 🔍 검색 중: battle pass – y9s2 – for honor
# ✅ 일반 결과: battle pass – y9s2 – for honor → appid 3793370
#
# 🔍 검색 중: 데스티니 가디언즈: 마녀 여왕
# ✅ 일반 결과: 데스티니 가디언즈: 마녀 여왕 → appid 1656330
#
# 🔍 검색 중: medal of honor™
# ✅ 일반 결과: medal of honor™ → appid 1402320
#
# 🔍 검색 중: 커맨드 앤 컨커 리마스터 컬렉션
# 🔍 필터링 결과에서 추출됨 → appid 1213210
#
# 🔍 검색 중: 강철 요새：시냅스 td
# ✅ 일반 결과: 강철 요새：시냅스 td → appid 2296550
#
# 🔍 검색 중: otherworld legends 战魂铭人
# ✅ 일반 결과: otherworld legends 战魂铭人 → appid 1761380
#
# 🔍 검색 중: age of empires iii: definitive edition (정식 게임)
# ✅ 일반 결과: age of empires iii: definitive edition (정식 게임) → appid 2477660
#
# 🔍 검색 중: wasd : 토리의 모험
# ✅ 일반 결과: wasd : 토리의 모험 → appid 3811390
#
# 🔍 검색 중: 3on3 freestyle – 2025 character access pass
# ✅ 일반 결과: 3on3 freestyle – 2025 character access pass → appid 3774100
#
# 🔍 검색 중: naruto -나루토- 질풍전 나루티밋 스톰 4 로드 투 보루토 확장판
# ✅ 일반 결과: naruto -나루토- 질풍전 나루티밋 스톰 4 로드 투 보루토 확장판 → appid 495160
#
# 🔍 검색 중: naruto shippuden: ultimate ninja storm 3 full burst hd
# ✅ 일반 결과: naruto shippuden: ultimate ninja storm 3 full burst hd → appid None
#
# 🔍 검색 중: 리볼트
# 🔍 필터링 결과에서 추출됨 → appid 287310
#
# 🔍 검색 중: battlefield 1 ™ shortcut 키트: 얼티메이트 번들
# 🔍 필터링 결과에서 추출됨 → appid 1238851
#
# 🔍 검색 중: 건쉽배틀 토탈워페어
# ✅ 일반 결과: 건쉽배틀 토탈워페어 → appid 3029540
#
# 🔍 검색 중: puzzle together multiplayer jigsaw puzzles
# ✅ 일반 결과: puzzle together multiplayer jigsaw puzzles → appid 1478220
#
# 🔍 검색 중: 내 전골에 뭐 넣었어?!
# ❌ appid 추출 실패
#
# 🔍 검색 중: angel legion
# ✅ 일반 결과: angel legion → appid 1333350
#
# 🔍 검색 중: 포탈 던전
# ✅ 일반 결과: 포탈 던전 → appid 1679220
#
# 🔍 검색 중: 슈퍼마켓 시뮬레이터
# ✅ 일반 결과: 슈퍼마켓 시뮬레이터 → appid 2961880
#
# 🔍 검색 중: ereadrone : fpv drone simulator
# ✅ 일반 결과: ereadrone : fpv drone simulator → appid 1301060
#
# 🔍 검색 중: stronghold legends: steam edition
# ✅ 일반 결과: stronghold legends: steam edition → appid 1172620
#
# 🔍 검색 중: 타이니 아쿠아리움 : 소셜 수족관
# ✅ 일반 결과: 타이니 아쿠아리움 : 소셜 수족관 → appid 2581950
#
# 🔍 검색 중: castle crashers®
# ✅ 일반 결과: castle crashers® → appid 204360
#
# 🔍 검색 중: 젠장! 미녀들한테 포위당했어!
# ✅ 일반 결과: 젠장! 미녀들한테 포위당했어! → appid 2322560
#
# 🔍 검색 중: 나루토 x 보루토 나루티밋 스톰 커넥션즈
# ✅ 일반 결과: 나루토 x 보루토 나루티밋 스톰 커넥션즈 → appid 1020790
#
# 🔍 검색 중: secrets of the revolution
# ✅ 일반 결과: secrets of the revolution → appid 324332
#
# 🔍 검색 중: 끝없는 앨리스
# ✅ 일반 결과: 끝없는 앨리스 → appid 2617100
#
# 🔍 검색 중: risk of rain 2: survivors of the void
# ✅ 일반 결과: risk of rain 2: survivors of the void → appid 1607890
#
# 🔍 검색 중: nebulous: fleet command 네뷸러스: 플릿 커맨드
# 🔍 필터링 결과에서 추출됨 → appid 887570
#
# 🔍 검색 중: 스톰 스트라이커
# ✅ 일반 결과: 스톰 스트라이커 → appid 2503740
#
# 🔍 검색 중: project: playtime
# ✅ 일반 결과: project: playtime → appid 1826140
#
# 🔍 검색 중: monster hunter rise: sunbreak 디럭스 키트
# ✅ 일반 결과: monster hunter rise: sunbreak 디럭스 키트 → appid 1913711
#
# 🔍 검색 중: captain coalheart – pirate hero skin – for honor
# ✅ 일반 결과: captain coalheart – pirate hero skin – for honor → appid 3793350
#
# 🔍 검색 중: 태고의 달인 쿵딱! 원더풀 페스티벌 pop 콜렉션
# ✅ 일반 결과: 태고의 달인 쿵딱! 원더풀 페스티벌 pop 콜렉션 → appid 3068540
#
# 🔍 검색 중: 크라임 보스: 록케이 시티 crime boss: rockay city
# ✅ 일반 결과: 크라임 보스: 록케이 시티 crime boss: rockay city → appid 2933080
#
# 🔍 검색 중: 렐릭 헌터스 레전드
# ✅ 일반 결과: 렐릭 헌터스 레전드 → appid 633080
#
# 🔍 검색 중: 워그루브
# ✅ 일반 결과: 워그루브 → appid 607050
#
# 🔍 검색 중: 바람의 크로노아 １＆２ 모험의 시작
# ✅ 일반 결과: 바람의 크로노아 １＆２ 모험의 시작 → appid 1730680
#
# 🔍 검색 중: forza horizon 5 보물 지도
# ✅ 일반 결과: forza horizon 5 보물 지도 → appid 1613285
#
# 🔍 검색 중: fantasy life i : 빙글빙글 용과 시간을 훔치는 소녀 : 에디션 업그레이드 (디지털 디럭스)
# ✅ 일반 결과: fantasy life i : 빙글빙글 용과 시간을 훔치는 소녀 : 에디션 업그레이드 (디지털 디럭스) → appid 3464380
#
# 🔍 검색 중: rocksmith® 2014 edition remastered learn & play
# ✅ 일반 결과: rocksmith® 2014 edition remastered learn & play → appid 2834910
#
# 🔍 검색 중: the crew motorfest year 1 pass
# ✅ 일반 결과: the crew motorfest year 1 pass → appid 2805000
#
# 🔍 검색 중: world of warships — 비바 프랑스!
# ✅ 일반 결과: world of warships — 비바 프랑스! → appid 3016850
#
# 🔍 검색 중: tom clancy's rainbow six® vegas 2
# ✅ 일반 결과: tom clancy's rainbow six® vegas 2 → appid 1173890
#
# 🔍 검색 중: riders republic™ year 1 pass
# ✅ 일반 결과: riders republic™ year 1 pass → appid 2466100
#
# 🔍 검색 중: sonic adventure 2
# ✅ 일반 결과: sonic adventure 2 → appid 2089840
#
# 🔍 검색 중: 애스트럴 어센트
# ✅ 일반 결과: 애스트럴 어센트 → appid 1280930
#
# 🔍 검색 중: battlefield 4™ 얼티메이트 숏컷 번들
# ✅ 일반 결과: battlefield 4™ 얼티메이트 숏컷 번들 → appid 1238871
#
# 🔍 검색 중: 바람의 크로노아 １＆２ 모험의 시작 스페셜 번들
# ✅ 일반 결과: 바람의 크로노아 １＆２ 모험의 시작 스페셜 번들 → appid 1930761
#
# 🔍 검색 중: road redemption: from road rash to road rage
# 🔍 필터링 결과에서 추출됨 → appid 727440
#
# 🔍 검색 중: hunt: showdown 1896 – frau perchta
# 🔍 필터링 결과에서 추출됨 → appid 2160330
#
# 🔍 검색 중: fbc : firebreak deluxe upgrade
# ✅ 일반 결과: fbc : firebreak deluxe upgrade → appid 3625720
#
# 🔍 검색 중: 체스
# ✅ 일반 결과: 체스 → appid 2965280
#
# 🔍 검색 중: dead island: riptide definitive edition
# ✅ 일반 결과: dead island: riptide definitive edition → appid None
#
# 🔍 검색 중: trine 2: complete story
# ✅ 일반 결과: trine 2: complete story → appid 35720
#
# 🔍 검색 중: iron harvest: rusviet revolution
# ✅ 일반 결과: iron harvest: rusviet revolution → appid None
#
# 🔍 검색 중: 바카라 온라인: baccarist
# ✅ 일반 결과: 바카라 온라인: baccarist → appid 3673460
#
# 🔍 검색 중: 젠장! 미녀들한테 포위당했어! 프리퀄
# ✅ 일반 결과: 젠장! 미녀들한테 포위당했어! 프리퀄 → appid 2322560
#
# 🔍 검색 중: metal waltz: anime tank girls
# ✅ 일반 결과: metal waltz: anime tank girls → appid 581130
#
# 🔍 검색 중: 스트롱홀드: 결정판
# ✅ 일반 결과: 스트롱홀드: 결정판 → appid 2140020
#
# 🔍 검색 중: 태고의 달인 쿵딱! 원더풀 페스티벌 vocaloid™ music 콜렉션
# ✅ 일반 결과: 태고의 달인 쿵딱! 원더풀 페스티벌 vocaloid™ music 콜렉션 → appid 3068550
#
# 🔍 검색 중: みんなで推理
# ✅ 일반 결과: みんなで推理 → appid 1973710
#
# 🔍 검색 중: hunt: showdown 1896 – fear the reaper
# 🔍 필터링 결과에서 추출됨 → appid 2133640
#
# 🔍 검색 중: tank force: 온라인 슈팅 게임
# ✅ 일반 결과: tank force: 온라인 슈팅 게임 → appid 604500
#
# 🔍 검색 중: need for speed™ most wanted premium modification unlock
# ✅ 일반 결과: need for speed™ most wanted premium modification unlock → appid 1193090
#
# 🔍 검색 중: 콜 오브 듀티®: 블랙 옵스 6 또는 콜 오브 듀티®: 워존 포인트
# ✅ 일반 결과: 콜 오브 듀티®: 블랙 옵스 6 또는 콜 오브 듀티®: 워존 포인트 → appid 2170970
#
# 🔍 검색 중: 모사 리나 mosa lina
# ✅ 일반 결과: 모사 리나 mosa lina → appid 2477090
#
# 🔍 검색 중: 크레이지 펫 쇼
# ✅ 일반 결과: 크레이지 펫 쇼 → appid 1390700
#
# 🔍 검색 중: trine enchanted edition
# ✅ 일반 결과: trine enchanted edition → appid None
#
# 🔍 검색 중: chill pulse
# ✅ 일반 결과: chill pulse → appid 2826180
#
# 🔍 검색 중: kanjozoku game レーサー online street racing & drift
# 🔍 필터링 결과에서 추출됨 → appid 2073470
#
# 🔍 검색 중: fortress 2 blue（疯狂坦克）
# ✅ 일반 결과: fortress 2 blue（疯狂坦克） → appid None
#
# 🔍 검색 중: trials evolution: gold edition
# ✅ 일반 결과: trials evolution: gold edition → appid 220160
#
# 🔍 검색 중: need for speed™ payback: pontiac firebird & aston martin db5 superbuild 번들
# 🔍 필터링 결과에서 추출됨 → appid 1328031
#
# 🔍 검색 중: sid meier's civilization® v
# ✅ 일반 결과: sid meier's civilization® v → appid 8930
#
# 🔍 검색 중: tom clancy’s the division™
# ✅ 일반 결과: tom clancy’s the division™ → appid 365590
#
# 🔍 검색 중: forbiddenword
# ✅ 일반 결과: forbiddenword → appid 2093220
#
# 🔍 검색 중: beach buggy racing 2: island adventure
# ✅ 일반 결과: beach buggy racing 2: island adventure → appid 1230800
#
# 🔍 검색 중: 커맨드 & 컨커 3: 케인의 분노
# ✅ 일반 결과: 커맨드 & 컨커 3: 케인의 분노 → appid 24810
#
# 🔍 검색 중: wrc 5 fia world rally championship
# ✅ 일반 결과: wrc 5 fia world rally championship → appid 621830
#
# 🔍 검색 중: bogos binted?
# ❌ appid 추출 실패
#
# 🔍 검색 중: borderlands game of the year enhanced
# ✅ 일반 결과: borderlands game of the year enhanced → appid 49520,207870,208690,213210,213230,213250,213780,218550,224200,230090
#
# 🔍 검색 중: 지뢰 찾기: 플레이 투게더
# ✅ 일반 결과: 지뢰 찾기: 플레이 투게더 → appid 2865580
#
# 🔍 검색 중: sébastien loeb rally evo
# ✅ 일반 결과: sébastien loeb rally evo → appid 2074070
#
# 🔍 검색 중: 그래픽 타워 디펜스
# ✅ 일반 결과: 그래픽 타워 디펜스 → appid 3650100
#
# 🔍 검색 중: 시드 마이어의 문명 vii: 히미코(고위 무녀) 페르소나
# ✅ 일반 결과: 시드 마이어의 문명 vii: 히미코(고위 무녀) 페르소나 → appid 3087260
#
# 🔍 검색 중: 시드 마이어의 문명 vii: 아소카(세계의 정복자) 페르소나
# ✅ 일반 결과: 시드 마이어의 문명 vii: 아소카(세계의 정복자) 페르소나 → appid 3087270
#
# 🔍 검색 중: r.a.w. realms of ancient war
# ✅ 일반 결과: r.a.w. realms of ancient war → appid 3017860
#
# 🔍 검색 중: 후즈후?
# ❌ appid 추출 실패
#
# 🔍 검색 중: up n' down
# ✅ 일반 결과: up n' down → appid 2520580
#
# 🔍 검색 중: tom clancy's endwar™
# 🔍 필터링 결과에서 추출됨 → appid 21800
#
# 🔍 검색 중: 원피스 해적무쌍 4 추가 에피소드 제2탄 "코비 분투 일기"&소울의 해도 2
# ✅ 일반 결과: 원피스 해적무쌍 4 추가 에피소드 제2탄 "코비 분투 일기"&소울의 해도 2 → appid 2617310
#
# 🔍 검색 중: lego® star wars™: 스카이워커 사가
# ✅ 일반 결과: lego® star wars™: 스카이워커 사가 → appid 920210
#
# 🔍 검색 중: trail out | moto rush
# ✅ 일반 결과: trail out | moto rush → appid 2399810
#
# 🔍 검색 중: dark messiah of might & magic
# ✅ 일반 결과: dark messiah of might & magic → appid 2071280
#
# 🔍 검색 중: 크레이지 펫 쇼: 해피 트리 프렌즈 에디션
# ✅ 일반 결과: 크레이지 펫 쇼: 해피 트리 프렌즈 에디션 → appid 2466420
#
# 🔍 검색 중: 러버 밴딧: rubber bandits
# ✅ 일반 결과: 러버 밴딧: rubber bandits → appid 1206610
#
# 🔍 검색 중: trials® rising
# ✅ 일반 결과: trials® rising → appid 3240220
#
# 🔍 검색 중: forza horizon 5 2018 ferrari fxx-k evo
# ✅ 일반 결과: forza horizon 5 2018 ferrari fxx-k evo → appid 1824142
#
# 🔍 검색 중: tales & tactics
# ✅ 일반 결과: tales & tactics → appid 1652250
#
# 🔍 검색 중: moto racer 4
# 🔍 필터링 결과에서 추출됨 → appid 417430
#
# 🔍 검색 중: 토람 온라인 online
# ✅ 일반 결과: 토람 온라인 online → appid 1827180
#
# 🔍 검색 중: 피규어 어드벤처 그룹
# ✅ 일반 결과: 피규어 어드벤처 그룹 → appid 2996570
#
# 🔍 검색 중: bloons td 5
# ✅ 일반 결과: bloons td 5 → appid 306020
#
# 🔍 검색 중: résop paz yandere true ( rpyt ) ( r-pyt ) ( resop paz )
# 🔍 필터링 결과에서 추출됨 → appid 2768440
#
# 🔍 검색 중: 빈 배틀즈
# ✅ 일반 결과: 빈 배틀즈 → appid 765410
#
# 🔍 검색 중: 식물 vs. 좀비™: 네이버빌의 대난투
# ✅ 일반 결과: 식물 vs. 좀비™: 네이버빌의 대난투 → appid 1262240
#
# 🔍 검색 중: 해리 포터: 퀴디치 챔피언
# ✅ 일반 결과: 해리 포터: 퀴디치 챔피언 → appid 2878600
#
# 🔍 검색 중: 奥丁为什么没胡子
# 🔍 필터링 결과에서 추출됨 → appid 1220670
#
# 🔍 검색 중: keystone titans vr
# 🔍 필터링 결과에서 추출됨 → appid 2398480
#
# 🔍 검색 중: loopcraft
# 🔍 필터링 결과에서 추출됨 → appid 871160
#
# 🔍 검색 중: greatest dungeon
# ✅ 일반 결과: greatest dungeon → appid 1086940
#
# 🔍 검색 중: rebirth x reverse mana
# ✅ 일반 결과: rebirth x reverse mana → appid 2128480
#
# 🔍 검색 중: looters inc.
# 🔍 필터링 결과에서 추출됨 → appid 3435180
#
# 🔍 검색 중: kreya: cursed rings
# 🔍 필터링 결과에서 추출됨 → appid 3656300
#
# 🔍 검색 중: cappy & tappy: temples of peril
# 🔍 필터링 결과에서 추출됨 → appid 3359860
#
# 🔍 검색 중: mini racer: mini 4wd
# ✅ 일반 결과: mini racer: mini 4wd → appid 320540
#
# 🔍 검색 중: rolling thunder: vietnam
# 🔍 필터링 결과에서 추출됨 → appid 3153900
#
# 🔍 검색 중: killer aces
# ✅ 일반 결과: killer aces → appid 1324970
#
# 🔍 검색 중: blackout: zero point
# ✅ 일반 결과: blackout: zero point → appid 2415000
#
# 🔍 검색 중: 플래닛 파티 타임 (planet party time)
# ✅ 일반 결과: 플래닛 파티 타임 (planet party time) → appid 3384570
#
# 🔍 검색 중: 블러드스테인드: 스칼렛 인게이지먼트
# ✅ 일반 결과: 블러드스테인드: 스칼렛 인게이지먼트 → appid 1883810
#
# 🔍 검색 중: 왕좌의 게임: 웨스테로스 전쟁
# 🔍 필터링 결과에서 추출됨 → appid 2838950
#
# 🔍 검색 중: 렘넌트의 바다
# ✅ 일반 결과: 렘넌트의 바다 → appid 3633680
#
# 🔍 검색 중: red rust pioneers: 멀티플레이어 서부 생존 시뮬레이터
# ✅ 일반 결과: red rust pioneers: 멀티플레이어 서부 생존 시뮬레이터 → appid 3664440
#
# 🔍 검색 중: 서브노티카 2
# ✅ 일반 결과: 서브노티카 2 → appid 1962700
#
# 🔍 검색 중: 梦西游
# 🔍 필터링 결과에서 추출됨 → appid 3676320
#
# 🔍 검색 중: throne tides
# ✅ 일반 결과: throne tides → appid 594570
#
# 🔍 검색 중: 상어 어푸
# ✅ 일반 결과: 상어 어푸 → appid 3848130
#
# 🔍 검색 중: 露比兔冒险 / adventures of ruby rabbit
# 🔍 필터링 결과에서 추출됨 → appid 1205570
#
# 🔍 검색 중: 목장의 숨결(breath of the pasture)
# ✅ 일반 결과: 목장의 숨결(breath of the pasture) → appid 2721990
#
# 🔍 검색 중: combat alchemy: autobattler
# 🔍 필터링 결과에서 추출됨 → appid 2680510
#
# 🔍 검색 중: paw party：cozy town / 萌爪派对：小镇时光
# 🔍 필터링 결과에서 추출됨 → appid 3743680
#
# 🔍 검색 중: loot goblin inc.
# 🔍 필터링 결과에서 추출됨 → appid 3034290
#
# 🔍 검색 중: breadskate
# 🔍 필터링 결과에서 추출됨 → appid 1677720
#
# 🔍 검색 중: fallen mankind mmo
# 🔍 필터링 결과에서 추출됨 → appid 2716280
#
# 🔍 검색 중: 水浒绘卷（water margin scrolls）
# ✅ 일반 결과: 水浒绘卷（water margin scrolls） → appid 3583540
#
# 🔍 검색 중: altiros
# 🔍 필터링 결과에서 추출됨 → appid 744200
#
# 🔍 검색 중: tides of tomorrow 🌊
# 🔍 필터링 결과에서 추출됨 → appid 2678080
#
# 🔍 검색 중: fadeland: fight clubs
# 🔍 필터링 결과에서 추출됨 → appid 3765040
#
# 🔍 검색 중: sorrow: rise of divinity
# 🔍 필터링 결과에서 추출됨 → appid 3504340
#
# 🔍 검색 중: tabletop fantasy war
# 🔍 필터링 결과에서 추출됨 → appid 3866000
#
# 🔍 검색 중: devastablance. inception of last day
# 🔍 필터링 결과에서 추출됨 → appid 3057510
#
# 🔍 검색 중: dawn: darkness awaits withstand the night
# ✅ 일반 결과: dawn: darkness awaits withstand the night → appid 1145350
#
# 🔍 검색 중: buscadores (seekers)
# 🔍 필터링 결과에서 추출됨 → appid 1924650
#
# 🔍 검색 중: memoryleak™
# 🔍 필터링 결과에서 추출됨 → appid 2763980
#
# 🔍 검색 중: feed me chef
# 🔍 필터링 결과에서 추출됨 → appid 2528430
#
# 🔍 검색 중: tamzin twins: the tyranny of tyrek
# 🔍 필터링 결과에서 추출됨 → appid 3082430
#
# 🔍 검색 중: black paradox reloaded
# 🔍 필터링 결과에서 추출됨 → appid 2977490
#
# 🔍 검색 중: divine move 神之手
# ✅ 일반 결과: divine move 神之手 → appid 3241110
#
# 🔍 검색 중: dark descent
# ✅ 일반 결과: dark descent → appid 1150440
#
# 🔍 검색 중: 인스파이럴: 인력의 메아리
# ✅ 일반 결과: 인스파이럴: 인력의 메아리 → appid 3638420
#
# 🔍 검색 중: mail it to the king!
# ✅ 일반 결과: mail it to the king! → appid None
#
# 🔍 검색 중: paintman go！
# 🔍 필터링 결과에서 추출됨 → appid 3406940
#
# 🔍 검색 중: moto roader 「モトローダー」
# 🔍 필터링 결과에서 추출됨 → appid 3577700
#
# 🔍 검색 중: 17.waves td
# ✅ 일반 결과: 17.waves td → appid 2369760
#
# 🔍 검색 중: 1！2！3！battle card!
# ✅ 일반 결과: 1！2！3！battle card! → appid 3601150
#
# 🔍 검색 중: primal survival
# ✅ 일반 결과: primal survival → appid 3620610
#
# 🔍 검색 중: exorkízein
# ✅ 일반 결과: exorkízein → appid 2813510
#
# 🔍 검색 중: fortune guy
# ✅ 일반 결과: fortune guy → appid 2887680
#
# 🔍 검색 중: spaceship idle: design, build, explore & battle
# ✅ 일반 결과: spaceship idle: design, build, explore & battle → appid 3454630
#
# 🔍 검색 중: 샌드박스 엔진
# ✅ 일반 결과: 샌드박스 엔진 → appid 926200
#
# 🔍 검색 중: rope it two
# ✅ 일반 결과: rope it two → appid 3560100
#
# 🔍 검색 중: escape protocol : online
# ✅ 일반 결과: escape protocol : online → appid 3655040
#
# 🔍 검색 중: mirage : lost in the liminal
# 🔍 필터링 결과에서 추출됨 → appid 2771970
#
# 🔍 검색 중: geno 2 the generals' orders
# ✅ 일반 결과: geno 2 the generals' orders → appid 1062160
#
# 🔍 검색 중: dwd: drunk wizard dungeoneer
# 🔍 필터링 결과에서 추출됨 → appid 3824820
#
# 🔍 검색 중: 뱀파이어의 각성: 엘프 소드 연대기 서바이벌 (vampire awakening: elven sword chronicles survival)
# ✅ 일반 결과: 뱀파이어의 각성: 엘프 소드 연대기 서바이벌 (vampire awakening: elven sword chronicles survival) → appid 3846800
#
# 🔍 검색 중: llamarpg: farm to fable
# 🔍 필터링 결과에서 추출됨 → appid 2778290
#
# 🔍 검색 중: kritter: defend together
# ✅ 일반 결과: kritter: defend together → appid 2103950
#
# 🔍 검색 중: zangyou
# 🔍 필터링 결과에서 추출됨 → appid 3805820
#
# 🔍 검색 중: among space
# ✅ 일반 결과: among space → appid 3022790
#
# 🔍 검색 중: 幸存机动队
# ✅ 일반 결과: 幸存机动队 → appid 3241110
#
# 🔍 검색 중: our journey: the silent voice
# ✅ 일반 결과: our journey: the silent voice → appid 2720730
#
# 🔍 검색 중: 쾅! 장난감 대결
# ✅ 일반 결과: 쾅! 장난감 대결 → appid 3743450
#
# 🔍 검색 중: christmas smash
# 🔍 필터링 결과에서 추출됨 → appid 2308050
#
# 🔍 검색 중: to the grave: the battle for faenora
# 🔍 필터링 결과에서 추출됨 → appid 2498260
#
# 🔍 검색 중: cook, serve, delicious: re-mustard!
# ✅ 일반 결과: cook, serve, delicious: re-mustard! → appid 3444630
#
# 🔍 검색 중: 좀비 처치!
# ✅ 일반 결과: 좀비 처치! → appid 3309070
#
# 🔍 검색 중: 烈焰狂奔
# 🔍 필터링 결과에서 추출됨 → appid 3362390
#
# 🔍 검색 중: arca
# ✅ 일반 결과: arca → appid 842120
#
# 🔍 검색 중: wrekless™
# 🔍 필터링 결과에서 추출됨 → appid 1931930
#
# 🔍 검색 중: lag kills
# ✅ 일반 결과: lag kills → appid 1461600
#
# 🔍 검색 중: espiocracy 에스피오크러시
# ✅ 일반 결과: espiocracy 에스피오크러시 → appid 1670650
#
# 🔍 검색 중: everstorm: extraction royale
# ✅ 일반 결과: everstorm: extraction royale → appid 1292510
#
# 🔍 검색 중: 东方妖灵传 / touhou legend of fairy souls
# 🔍 필터링 결과에서 추출됨 → appid 2287780
#
# 🔍 검색 중: primal hunt
# ✅ 일반 결과: primal hunt → appid 1938010
#
# 🔍 검색 중: nihongo quest
# 🔍 필터링 결과에서 추출됨 → appid 1556070
#
# 🔍 검색 중: backrooms #999999999
# 🔍 필터링 결과에서 추출됨 → appid 2785620
#
# 🔍 검색 중: epic cards battle 3 (tcg)
# ✅ 일반 결과: epic cards battle 3 (tcg) → appid 2842430
#
# 🔍 검색 중: world of stickman classic rts
# ✅ 일반 결과: world of stickman classic rts → appid 1934680
#
# 🔍 검색 중: 에테리아
# ✅ 일반 결과: 에테리아 → appid 2084970
#
# 🔍 검색 중: 연운
# ✅ 일반 결과: 연운 → appid 3564740
#
# 🔍 검색 중: drug schedule
# ✅ 일반 결과: drug schedule → appid 1601260
#
# 🔍 검색 중: 일곱 개의 대죄: origin
# ✅ 일반 결과: 일곱 개의 대죄: origin → appid 3679080
#
# 🔍 검색 중: 腐朽默示 / revelation of decay
# 🔍 필터링 결과에서 추출됨 → appid 2975680
#
# 🔍 검색 중: order: the new dawn
# ✅ 일반 결과: order: the new dawn → appid 3080070
#
# 🔍 검색 중: heroes of might and magic: olden era 히어로즈 오브 마이트 앤 매직: 올든 에라
# ✅ 일반 결과: heroes of might and magic: olden era 히어로즈 오브 마이트 앤 매직: 올든 에라 → appid 3105440
#
# 🔍 검색 중: long drive north: 협동 rv 시뮬레이터
# ✅ 일반 결과: long drive north: 협동 rv 시뮬레이터 → appid 3179350
#
# 🔍 검색 중: 빼앗긴 왕국: 생존자들
# ✅ 일반 결과: 빼앗긴 왕국: 생존자들 → appid 3228580
#
# 🔍 검색 중: beast : bio exo arena suit team
# ✅ 일반 결과: beast : bio exo arena suit team → appid 3239670
#
# 🔍 검색 중: 비비드 월드
# ✅ 일반 결과: 비비드 월드 → appid 2468550
#
# 🔍 검색 중: water me & you
# ✅ 일반 결과: water me & you → appid 2509360
#
# 🔍 검색 중: vrso: bare knuckle fighting
# ✅ 일반 결과: vrso: bare knuckle fighting → appid 985890
#
# 🔍 검색 중: the masquerade
# ✅ 일반 결과: the masquerade → appid 2595530
#
# 🔍 검색 중: finch & archie
# 🔍 필터링 결과에서 추출됨 → appid 2642500
#
# 🔍 검색 중: 메카 사이멀택틱스
# ✅ 일반 결과: 메카 사이멀택틱스 → appid 2738660
#
# 🔍 검색 중: the whims of the gods 🏝️🏠🌋
# 🔍 필터링 결과에서 추출됨 → appid 2642390
#
# 🔍 검색 중: bullet blade
# ✅ 일반 결과: bullet blade → appid None
#
# 🔍 검색 중: blades, bows and magic
# ✅ 일반 결과: blades, bows and magic → appid 3182730
#
# 🔍 검색 중: the naki files
# 🔍 필터링 결과에서 추출됨 → appid 3352850
#
# 🔍 검색 중: bandits vs lords: epic clash
# ✅ 일반 결과: bandits vs lords: epic clash → appid 3142050
#
# 🔍 검색 중: nitpick: i must hunt
# ✅ 일반 결과: nitpick: i must hunt → appid 865820
#
# 🔍 검색 중: chessplus: combine & conquer
# 🔍 필터링 결과에서 추출됨 → appid 3273750
#
# 🔍 검색 중: 치킨 런: 후다닭 구출 작전
# ✅ 일반 결과: 치킨 런: 후다닭 구출 작전 → appid 3419690
#
# 🔍 검색 중: 도라™: 열대우림 구조대
# 🔍 필터링 결과에서 추출됨 → appid 3273550
#
# 🔍 검색 중: 더블 드래곤 리바이브
# ✅ 일반 결과: 더블 드래곤 리바이브 → appid 3012220
#
# 🔍 검색 중: totenkampf : 애니메이션 waifus 대 ww2 좀비
# ✅ 일반 결과: totenkampf : 애니메이션 waifus 대 ww2 좀비 → appid 3827370
#
# 🔍 검색 중: 방 탈출 시뮬레이터2
# ✅ 일반 결과: 방 탈출 시뮬레이터2 → appid 2879840
#
# 🔍 검색 중: summit smash
# ✅ 일반 결과: summit smash → appid 617830
#
# 🔍 검색 중: wizard's wrath legends
# ✅ 일반 결과: wizard's wrath legends → appid None
#
# 🔍 검색 중: midnight escape
# ✅ 일반 결과: midnight escape → appid 2795540
#
# 🔍 검색 중: ultima chess vr
# ✅ 일반 결과: ultima chess vr → appid 3551180
#
# 🔍 검색 중: 나이트워드
# ✅ 일반 결과: 나이트워드 → appid None
#
# 🔍 검색 중: odra online
# ✅ 일반 결과: odra online → appid 3347800
#
# 🔍 검색 중: gaionin war don't combine 【混ぜるな危険】
# ✅ 일반 결과: gaionin war don't combine 【混ぜるな危険】 → appid 3879710
#
# 🔍 검색 중: 딥 블루: 삼키고 진화하라
# ✅ 일반 결과: 딥 블루: 삼키고 진화하라 → appid 3553750
#
# 🔍 검색 중: bound: gulag getaway
# 🔍 필터링 결과에서 추출됨 → appid 3273060
#
# 🔍 검색 중: stash: a card looter
# 🔍 필터링 결과에서 추출됨 → appid 3296910
#
# 🔍 검색 중: seagulls: crappy situation
# 🔍 필터링 결과에서 추출됨 → appid 2843720
#
# 🔍 검색 중: hidengen
# 🔍 필터링 결과에서 추출됨 → appid 3698730
#
# 🔍 검색 중: hegemonism: cold war
# 🔍 필터링 결과에서 추출됨 → appid 3846040
#
# 🔍 검색 중: 鸡飞狗跳 / chicken jump, puppy jump
# 🔍 필터링 결과에서 추출됨 → appid 3828740
#
# 🔍 검색 중: fish hunters: the most ridiculous fishing simulator 🐟
# ✅ 일반 결과: fish hunters: the most ridiculous fishing simulator 🐟 → appid 3468330
#
# 🔍 검색 중: 소닉 레이싱 크로스월드
# ✅ 일반 결과: 소닉 레이싱 크로스월드 → appid 2486820
#
# 🔍 검색 중: job battle simulator: 물리적으로 정확한 시뮬레이션
# ✅ 일반 결과: job battle simulator: 물리적으로 정확한 시뮬레이션 → appid 3671980
#
# 🔍 검색 중: dreamworks 개비의 매직 하우스: 파티 준비 끝
# 🔍 필터링 결과에서 추출됨 → appid 3222830
#
# 🔍 검색 중: 토와와 신목에 선택받은 아이들
# ✅ 일반 결과: 토와와 신목에 선택받은 아이들 → appid 1910090
#
# 🔍 검색 중: 젤리군단 jelly troops
# ✅ 일반 결과: 젤리군단 jelly troops → appid 3084910
#
# 🔍 검색 중: bratz® 리듬 & 스타일
# 🔍 필터링 결과에서 추출됨 → appid 3212580
#
# 🔍 검색 중: try not to scream : coop
# ✅ 일반 결과: try not to scream : coop → appid 3080960
#
# 🔍 검색 중: arm of satan: chapter 1
# ✅ 일반 결과: arm of satan: chapter 1 → appid 287290
#
# 🔍 검색 중: monkey fruit fight!
# ✅ 일반 결과: monkey fruit fight! → appid 3764780
#
# 🔍 검색 중: 블록깨짐
# ✅ 일반 결과: 블록깨짐 → appid 3668530
#
# 🔍 검색 중: rts chess
# ✅ 일반 결과: rts chess → appid 3841280
#
# 🔍 검색 중: blind trust: the city
# ✅ 일반 결과: blind trust: the city → appid None
#
# 🔍 검색 중: grind hero: mmorpg
# ✅ 일반 결과: grind hero: mmorpg → appid 3119830
#
# 🔍 검색 중: 피자 밴딧
# ✅ 일반 결과: 피자 밴딧 → appid 2475010
#
# 🔍 검색 중: 프랑스 브라세리 시뮬레이터
# ✅ 일반 결과: 프랑스 브라세리 시뮬레이터 → appid 3058360
#
# 🔍 검색 중: 서머너즈 워: 러쉬
# ✅ 일반 결과: 서머너즈 워: 러쉬 → appid 3813590
#
# 🔍 검색 중: 청소는 맡겨줘
# ✅ 일반 결과: 청소는 맡겨줘 → appid 2451310
#
# 🔍 검색 중: 던전 스토커즈
# ✅ 일반 결과: 던전 스토커즈 → appid 2468730
#
# 🔍 검색 중: 후프 파이터스: 파티 농구
# ✅ 일반 결과: 후프 파이터스: 파티 농구 → appid 2244520
#
# 🔍 검색 중: gradius origins
# ✅ 일반 결과: gradius origins → appid 2897590
#
# 🔍 검색 중: shattered soul
# ✅ 일반 결과: shattered soul → appid 2542120
#
# 🔍 검색 중: bee simulator: the hive
# ✅ 일반 결과: bee simulator: the hive → appid 3348910
#
# 🔍 검색 중: esophaguys
# ❌ appid 추출 실패
#
# 🔍 검색 중: 기하학 슈터 pro
# ✅ 일반 결과: 기하학 슈터 pro → appid 3195710
#
# 🔍 검색 중: 오행기(五行棋)
# ✅ 일반 결과: 오행기(五行棋) → appid 3801180
#
# 🔍 검색 중: fantasy hearts
# ✅ 일반 결과: fantasy hearts → appid 1903340
#
# 🔍 검색 중: 라이브 렌즈
# 🔍 필터링 결과에서 추출됨 → appid 3055480
#
# 🔍 검색 중: hololive holo's 화투
# ✅ 일반 결과: hololive holo's 화투 → appid 3327640
#
# 🔍 검색 중: sherlock: 숨은그림찾기 및 매치-3 미스터리
# ✅ 일반 결과: sherlock: 숨은그림찾기 및 매치-3 미스터리 → appid 3760230
#
# 🔍 검색 중: t.b.m ~ donation <3
# ❌ appid 추출 실패
#
# 🔍 검색 중: snail simulator: full metal slug
# 🔍 필터링 결과에서 추출됨 → appid 3837000
#
# 🔍 검색 중: 유령 주방
# ✅ 일반 결과: 유령 주방 → appid 3572120
#
# 🔍 검색 중: 용감한 영혼
# 🔍 필터링 결과에서 추출됨 → appid 2980240
#
# 🔍 검색 중: 三国.争霸
# ✅ 일반 결과: 三国.争霸 → appid 1508740
#
# 🔍 검색 중: 오토게임 디럭스
# ✅ 일반 결과: 오토게임 디럭스 → appid 1952450
#
# 🔍 검색 중: war dust vr : storm | 32vs32 battlefields
# ✅ 일반 결과: war dust vr : storm | 32vs32 battlefields → appid None
#
# 🔍 검색 중: mightykingdom
# 🔍 필터링 결과에서 추출됨 → appid 3106580
#
# 🔍 검색 중: arc tcg
# ✅ 일반 결과: arc tcg → appid 2842430
#
# 🔍 검색 중: 三国.群英录
# ✅ 일반 결과: 三国.群英录 → appid 3241110
#
# 🔍 검색 중: 에서 ~에 의해
# ✅ 일반 결과: 에서 ~에 의해 → appid 3630600
#
# 🔍 검색 중: pyramidvalley: reborn
# 🔍 필터링 결과에서 추출됨 → appid 3618760
#
# 🔍 검색 중: 데스티니 가디언즈: 예언의 해 얼티밋 에디션 업그레이드
# ✅ 일반 결과: 데스티니 가디언즈: 예언의 해 얼티밋 에디션 업그레이드 → appid 3205620
#
# 🔍 검색 중: 데스티니 가디언즈: 예언의 해
# ✅ 일반 결과: 데스티니 가디언즈: 예언의 해 → appid 3489050
#
# 🔍 검색 중: 데스티니 가디언즈: 예언의 해 얼티밋 에디션
# ✅ 일반 결과: 데스티니 가디언즈: 예언의 해 얼티밋 에디션 → appid 3186500
#
# 🔍 검색 중: 오델로: 배틀 로얄
# ✅ 일반 결과: 오델로: 배틀 로얄 → appid 3682440
#
# 🔍 검색 중: kickback: shoot to move! 👾
# ✅ 일반 결과: kickback: shoot to move! 👾 → appid 2753870
#
# 🔍 검색 중: c.a.s.t. (chernozem anomaly strike team)
# 🔍 필터링 결과에서 추출됨 → appid 3140620
#
# 🔍 검색 중: dr voss’ escape room
# ✅ 일반 결과: dr voss’ escape room → appid None
#
# 🔍 검색 중: 언캐니 미궁: 9번째 참가자
# 🔍 필터링 결과에서 추출됨 → appid 2812670
#
# 🔍 검색 중: scope battle royale
# ✅ 일반 결과: scope battle royale → appid 671860
#
# 🔍 검색 중: 월드 오브 워쉽 x 블루 아카이브 — 마스터 시바의 라멘 장사
# ✅ 일반 결과: 월드 오브 워쉽 x 블루 아카이브 — 마스터 시바의 라멘 장사 → appid 3851660
#
# 🔍 검색 중: 至尊传说
# ✅ 일반 결과: 至尊传说 → appid 1508740
#
# 🔍 검색 중: earth: revival
# ✅ 일반 결과: earth: revival → appid 887380
#
# 🔍 검색 중: ac130이 좀비들을 제거합니다.
# 🔍 필터링 결과에서 추출됨 → appid 3536480
#
# 🔍 검색 중: mycopunk: 곰팡이 버스터즈
# ✅ 일반 결과: mycopunk: 곰팡이 버스터즈 → appid 3247750
#
# 🔍 검색 중: 세븐하츠 (seven hearts)
# ✅ 일반 결과: 세븐하츠 (seven hearts) → appid 3748090
#
# 🔍 검색 중: 드론:현대전
# ❌ appid 추출 실패
#
# 🔍 검색 중: warface: clutch — 독립기념일
# ✅ 일반 결과: warface: clutch — 독립기념일 → appid 3840960
#
# 🔍 검색 중: fishing friends 3d
# ✅ 일반 결과: fishing friends 3d → appid 3240220
#
# 🔍 검색 중: motion soccer pro
# ✅ 일반 결과: motion soccer pro → appid 3137350
#
# 🔍 검색 중: 官將首黃金甲系列- guan jian shou gold series
# 🔍 필터링 결과에서 추출됨 → appid 3678680
#
# 🔍 검색 중: 兔子制服系列- uniform series
# 🔍 필터링 결과에서 추출됨 → appid 3547950
#
# 🔍 검색 중: melon simulator™
# ✅ 일반 결과: melon simulator™ → appid 3706950
#
# 🔍 검색 중: 아카디아: 구름에 묶인 세계
# ✅ 일반 결과: 아카디아: 구름에 묶인 세계 → appid 3616630
#
# 🔍 검색 중: journey to the west(暴躁西游)
# 🔍 필터링 결과에서 추출됨 → appid 2659880
#
# 🔍 검색 중: frick it
# 🔍 필터링 결과에서 추출됨 → appid 3397400
#
# 🔍 검색 중: 내 목장
# 🔍 필터링 결과에서 추출됨 → appid 2966520
#
# 🔍 검색 중: 마지막 저항
# ✅ 일반 결과: 마지막 저항 → appid 3769120
#
# 🔍 검색 중: 동방 배구
# ✅ 일반 결과: 동방 배구 → appid 3813380
#
# 🔍 검색 중: escapethebrainrots
# 🔍 필터링 결과에서 추출됨 → appid 3781690
#
# 🔍 검색 중: vrider sbk™
# ✅ 일반 결과: vrider sbk™ → appid 3145740
#
# 🔍 검색 중: walkabout mini golf: crystal lair
# ✅ 일반 결과: walkabout mini golf: crystal lair → appid 3680590
#
# 🔍 검색 중: holoreversi
# 🔍 필터링 결과에서 추출됨 → appid 3446980
#
# 🔍 검색 중: ヴィンテージカード解放vol.1
# 🔍 필터링 결과에서 추출됨 → appid 3619670
#
# 🔍 검색 중: 4枚コンプリートセット11「dz-bt05」
# 🔍 필터링 결과에서 추출됨 → appid 3619680
#
# 🔍 검색 중: カードファイト!! ヴァンガード dd2：カード解放vol.2【dz-bt05】「天智覚命」
# 🔍 필터링 결과에서 추출됨 → appid 3332360
#
# 🔍 검색 중: evercore heroes : ascension
# 🔍 필터링 결과에서 추출됨 → appid 2586780
#
# 🔍 검색 중: no retreat! the russian front
# 🔍 필터링 결과에서 추출됨 → appid 2869590
#
# 🔍 검색 중: 히어로즈 오브 드래곤 마운틴
# ✅ 일반 결과: 히어로즈 오브 드래곤 마운틴 → appid 2733070
#
# 🔍 검색 중: summer bundle
# ✅ 일반 결과: summer bundle → appid None
#
# 🔍 검색 중: 오버워치 2: 리퍼 완전한 신화 무기 스킨 묶음 상품
# ✅ 일반 결과: 오버워치 2: 리퍼 완전한 신화 무기 스킨 묶음 상품 → appid 3665200
#
# 🔍 검색 중: nanomon virtual pet
# ✅ 일반 결과: nanomon virtual pet → appid 1498060
#
# 🔍 검색 중: naica online
# 🔍 필터링 결과에서 추출됨 → appid 3562850
#
# 🔍 검색 중: 3dsen vr
# 🔍 필터링 결과에서 추출됨 → appid 954280
#
# 🔍 검색 중: 3dsen pc
# 🔍 필터링 결과에서 추출됨 → appid 1147940
#
# 🔍 검색 중: 잊혀진 여행
# ✅ 일반 결과: 잊혀진 여행 → appid 3183310
#
# 🔍 검색 중: mitos.is: og
# 🔍 필터링 결과에서 추출됨 → appid 3747300
#
# 🔍 검색 중: 천지를 돌리다
# ✅ 일반 결과: 천지를 돌리다 → appid 3745420
#
# 🔍 검색 중: roguebots arena
# 🔍 필터링 결과에서 추출됨 → appid 3423650
#
# 🔍 검색 중: wingspan (윙스팬): 아시아 확장
# ✅ 일반 결과: wingspan (윙스팬): 아시아 확장 → appid 3362880
#
# 🔍 검색 중: 迷你王国战争 mini kingdom wars
# ✅ 일반 결과: 迷你王国战争 mini kingdom wars → appid 2425740
#
# 🔍 검색 중: virtual frenzy- nexus corps
# 🔍 필터링 결과에서 추출됨 → appid 3598250
#
# 🔍 검색 중: 다이쇼: 사무라이 서바이벌 rpg
# ✅ 일반 결과: 다이쇼: 사무라이 서바이벌 rpg → appid 2502650
#
# 🔍 검색 중: carrom 2.0 || كيرم 2.0
# ✅ 일반 결과: carrom 2.0 || كيرم 2.0 → appid 550
#
# 🔍 검색 중: war lords 战争领主
# ✅ 일반 결과: war lords 战争领主 → appid 3241110
#
# 🔍 검색 중: drift legends 2 tuner
# ✅ 일반 결과: drift legends 2 tuner → appid 3707430
#
# 🔍 검색 중: drift legends 2 legendary
# ✅ 일반 결과: drift legends 2 legendary → appid 3707440
#
# 🔍 검색 중: drift legends 2 elite
# ✅ 일반 결과: drift legends 2 elite → appid 3707460
#
# 🔍 검색 중: drift legends 2 expert
# ✅ 일반 결과: drift legends 2 expert → appid 3707450
#
# 🔍 검색 중: drift legends 2 professional
# ✅ 일반 결과: drift legends 2 professional → appid 3707420
#
# 🔍 검색 중: drift legends 2 amateur
# ✅ 일반 결과: drift legends 2 amateur → appid 3707410
#
# 🔍 검색 중: drift legends 2 beginner
# ✅ 일반 결과: drift legends 2 beginner → appid 3681930
#
# 🔍 검색 중: fantasy car : car design simulator 造车模拟器
# ✅ 일반 결과: fantasy car : car design simulator 造车模拟器 → appid 3241110
#
# 🔍 검색 중: 서부로의 싸움
# ✅ 일반 결과: 서부로의 싸움 → appid 2870150
#
# 🔍 검색 중: 팝유컴 더 많은 의상 업그레이드 패키지
# ✅ 일반 결과: 팝유컴 더 많은 의상 업그레이드 패키지 → appid 3025670
#
# 🔍 검색 중: trackdown: genesis
# 🔍 필터링 결과에서 추출됨 → appid 3330350
#
# 🔍 검색 중: redroom
# 🔍 필터링 결과에서 추출됨 → appid 2894510
#
# 🔍 검색 중: disney illusion island starring mickey and friends
# ✅ 일반 결과: disney illusion island starring mickey and friends → appid 2054660
#
# 🔍 검색 중: ヴィクトルズ・テスト・ナイト　レーヴス
# 🔍 필터링 결과에서 추출됨 → appid 2786700
#
# 🔍 검색 중: 극비 수련-8
# ✅ 일반 결과: 극비 수련-8 → appid 3601280
#
# 🔍 검색 중: 인술 특별 수련 제44탄 히단
# ✅ 일반 결과: 인술 특별 수련 제44탄 히단 → appid 3601230
#
# 🔍 검색 중: powerwash simulator 머킹엄 파일 제6탄
# ✅ 일반 결과: powerwash simulator 머킹엄 파일 제6탄 → appid 3202510
#
# 🔍 검색 중: maniac: hunt or be hunted
# ✅ 일반 결과: maniac: hunt or be hunted → appid 1089270
#
# 🔍 검색 중: sahur: escape together
# 🔍 필터링 결과에서 추출됨 → appid 3736520
#
# 🔍 검색 중: 안개의 성
# ✅ 일반 결과: 안개의 성 → appid 3505060
#
# 🔍 검색 중: 奇妙大富翁(wonderful richman)
# 🔍 필터링 결과에서 추출됨 → appid 2771380
#
# 🔍 검색 중: 카지노 룰렛: roulettist
# ✅ 일반 결과: 카지노 룰렛: roulettist → appid 3601420
#
# 🔍 검색 중: sea of stars: throes of the watchmaker
# ✅ 일반 결과: sea of stars: throes of the watchmaker → appid 3457510
#
# 🔍 검색 중: flight runner universe
# 🔍 필터링 결과에서 추출됨 → appid 1146710
#
# 🔍 검색 중: strange shores: social desktop fishing
# 🔍 필터링 결과에서 추출됨 → appid 3593500
#
# 🔍 검색 중: 시드 마이어의 문명 vii: 크세르크세스(아케메네스의 후예) 페르소나
# ✅ 일반 결과: 시드 마이어의 문명 vii: 크세르크세스(아케메네스의 후예) 페르소나 → appid 3087220
#
# 🔍 검색 중: 시드 마이어의 문명 vii: 프리드리히(바로크) 페르소나
# ✅ 일반 결과: 시드 마이어의 문명 vii: 프리드리히(바로크) 페르소나 → appid 3087240
#
# 🔍 검색 중: nubs! arena
# ✅ 일반 결과: nubs! arena → appid 2337860
#
# 🔍 검색 중: 三国.群英志
# ✅ 일반 결과: 三国.群英志 → appid 3241110
#
# 🔍 검색 중: azazel gamble 阿撒兹勒赌局
# 🔍 필터링 결과에서 추출됨 → appid 3438900
#
# 🔍 검색 중: the key
# ✅ 일반 결과: the key → appid 2195200
#
# 🔍 검색 중: 百鬼之王-中式.恐怖.卡牌.遊戲
# ✅ 일반 결과: 百鬼之王-中式.恐怖.卡牌.遊戲 → appid 3241110
#
# 🔍 검색 중: 至尊战神传奇
# ✅ 일반 결과: 至尊战神传奇 → appid 1508740
#
# 🔍 검색 중: rotsp: the cosmic hoarder upgrade
# ✅ 일반 결과: rotsp: the cosmic hoarder upgrade → appid 3654280
#
# 🔍 검색 중: football heroes league: founder's bundle
# ✅ 일반 결과: football heroes league: founder's bundle → appid 3286750
#
# 🔍 검색 중: 오목
# ✅ 일반 결과: 오목 → appid 1555400
#
# 🔍 검색 중: lunch: the card game
# ✅ 일반 결과: lunch: the card game → appid 544810
#
# 🔍 검색 중: ™انتم السابقون
# 🔍 필터링 결과에서 추출됨 → appid 3666640
#
# 🔍 검색 중: walkabout mini golf: raptor cliff's
# ✅ 일반 결과: walkabout mini golf: raptor cliff's → appid 3526580
#
# 🔍 검색 중: 強襲装甲少女大戦　ヴァシレイア
# ❌ appid 추출 실패
#
# 🔍 검색 중: 『鬼太郎誕生 ゲゲゲの謎』コラボコスチューム（鬼太郎の父・水木）
# 🔍 필터링 결과에서 추출됨 → appid 3675370
#
# 🔍 검색 중: worlds of aria: fredo's games
# ✅ 일반 결과: worlds of aria: fredo's games → appid 2833600
#
# 🔍 검색 중: 레이싱카:스톰 트래블
# ✅ 일반 결과: 레이싱카:스톰 트래블 → appid 2399200
#
# 🔍 검색 중: 잭과 탐정: 블랙 매직 확장판
# ✅ 일반 결과: 잭과 탐정: 블랙 매직 확장판 → appid 3561450
#
# 🔍 검색 중: 블랙잭 21: blackjackist
# ✅ 일반 결과: 블랙잭 21: blackjackist → appid 3594780
#
# 🔍 검색 중: wild west : the last cowboy
# ✅ 일반 결과: wild west : the last cowboy → appid 3652620
#
# 🔍 검색 중: калибр: набор «в последний миг»
# 🔍 필터링 결과에서 추출됨 → appid 3526040
#
# 🔍 검색 중: калибр: набор «снайперская доля»
# 🔍 필터링 결과에서 추출됨 → appid 3526030
#
# 🔍 검색 중: калибр: набор «коровка»
# 🔍 필터링 결과에서 추출됨 → appid 3526020
#
# 🔍 검색 중: калибр: набор «улицы разбитых фонарей»
# 🔍 필터링 결과에서 추출됨 → appid 3526010
#
# 🔍 검색 중: калибр: набор «топор войны»
# 🔍 필터링 결과에서 추출됨 → appid 3526000
#
# 🔍 검색 중: калибр: набор «вместе навсегда»
# 🔍 필터링 결과에서 추출됨 → appid 3525990
#
# 🔍 검색 중: калибр: набор «луч надежды»
# 🔍 필터링 결과에서 추출됨 → appid 3525980
#
# 🔍 검색 중: калибр: набор «берсерк»
# 🔍 필터링 결과에서 추출됨 → appid 2440199
#
# 🔍 검색 중: калибр: оружейный набор
# 🔍 필터링 결과에서 추출됨 → appid 2440198
#
# 🔍 검색 중: калибр: набор сокола «форт»
# 🔍 필터링 결과에서 추출됨 → appid 2440197
#
# 🔍 검색 중: калибр: набор баррейры «тайфун»
# 🔍 필터링 결과에서 추출됨 → appid 2440196
#
# 🔍 검색 중: калибр: боевой набор багги «каракурт»
# 🔍 필터링 결과에서 추출됨 → appid 2440195
#
# 🔍 검색 중: 沙城.传奇
# ✅ 일반 결과: 沙城.传奇 → appid 3036080
#
# 🔍 검색 중: proptop demo
# 🔍 필터링 결과에서 추출됨 → appid 3617310
#
# 🔍 검색 중: isle of the night: pirate survivors
# ✅ 일반 결과: isle of the night: pirate survivors → appid 1206200
#
# 🔍 검색 중: metrogether train simulator
# 🔍 필터링 결과에서 추출됨 → appid 3239770
#
# 🔍 검색 중: social status: life simulator
# ✅ 일반 결과: social status: life simulator → appid 1144200
#
# 🔍 검색 중: 요새 도시
# ✅ 일반 결과: 요새 도시 → appid 2115760
#
# 🔍 검색 중: 신 소환 방어선
# ✅ 일반 결과: 신 소환 방어선 → appid 3581570
#
# 🔍 검색 중: tidal shock: off the hook
# ✅ 일반 결과: tidal shock: off the hook → appid 1659420
#
# 🔍 검색 중: hardware store simulator / 하드웨어 스토어 시뮬레이터
# ✅ 일반 결과: hardware store simulator / 하드웨어 스토어 시뮬레이터 → appid 3358560
#
# 🔍 검색 중: polygeddon
# 🔍 필터링 결과에서 추출됨 → appid 2067020
#
# 🔍 검색 중: polterguys: possession party
# ✅ 일반 결과: polterguys: possession party → appid None
#
# 🔍 검색 중: powerwash simulator 머킹엄 파일 제5탄
# ✅ 일반 결과: powerwash simulator 머킹엄 파일 제5탄 → appid 3202500
#
# 🔍 검색 중: キャラクターセット04「西園寺ユナ」
# 🔍 필터링 결과에서 추출됨 → appid 3493520
#
# 🔍 검색 중: キャラクターセット03「黒崎キョウマ」
# 🔍 필터링 결과에서 추출됨 → appid 3493510
#
# 🔍 검색 중: キャラクターセット02「鼎センカ」
# 🔍 필터링 결과에서 추출됨 → appid 3493500
#
# 🔍 검색 중: カードファイト!! ヴァンガード dd2：カード解放vol.1【dz-bt04】宿命決戦
# 🔍 필터링 결과에서 추출됨 → appid 3332330
#
# 🔍 검색 중: キャラクターセット01「向江ジンキ」
# 🔍 필터링 결과에서 추출됨 → appid 3493490
#
# 🔍 검색 중: 탁상 전쟁: 군단 난투
# ✅ 일반 결과: 탁상 전쟁: 군단 난투 → appid 3124850
#
# 🔍 검색 중: night club simulator: prolouge
# ✅ 일반 결과: night club simulator: prolouge → appid 2943670
#
# 🔍 검색 중: wild assault / 兽猎突袭
# 🔍 필터링 결과에서 추출됨 → appid 2827230
#
# 🔍 검색 중: 스노우 브라더스 2 스페셜
# ✅ 일반 결과: 스노우 브라더스 2 스페셜 → appid 2340640
#
# 🔍 검색 중: polclash
# 🔍 필터링 결과에서 추출됨 → appid 3228160
#
# 🔍 검색 중: pinchcliffe grand prix minigames
# ✅ 일반 결과: pinchcliffe grand prix minigames → appid 848960
#
# 🔍 검색 중: backrooms escape protocol
# 🔍 필터링 결과에서 추출됨 → appid 3575840
#
# 🔍 검색 중: 末日战姬-二次元.策略.卡牌.游戏
# 🔍 필터링 결과에서 추출됨 → appid 3607700
#
# 🔍 검색 중: 部落召唤 call of clans
# ✅ 일반 결과: 部落召唤 call of clans → appid 3384440
#
# 🔍 검색 중: emperor of the fading suns enhanced
# ✅ 일반 결과: emperor of the fading suns enhanced → appid 2192600
#
# 🔍 검색 중: 悠星大陆『elysium expanse』bd构筑二次元mmorpg
# 🔍 필터링 결과에서 추출됨 → appid 3362120
#
# 🔍 검색 중: sucker head: bodycam
# ✅ 일반 결과: sucker head: bodycam → appid 3227810
#
# 🔍 검색 중: 마드- 리치 마작(mahjong dream)
# ✅ 일반 결과: 마드- 리치 마작(mahjong dream) → appid 3592070
#
# 🔍 검색 중: echofall
# 🔍 필터링 결과에서 추출됨 → appid 3597980
#
# 🔍 검색 중: lil lootin lizards
# 🔍 필터링 결과에서 추출됨 → appid 3405010
#
# 🔍 검색 중: gawaiigo
# 🔍 필터링 결과에서 추출됨 → appid 3075270
#
# 🔍 검색 중: jumpscare simulator: deluxe supporter edition
# ✅ 일반 결과: jumpscare simulator: deluxe supporter edition → appid None
#
# 🔍 검색 중: jumpscare simulator: system breach
# ✅ 일반 결과: jumpscare simulator: system breach → appid 3551600
#
# 🔍 검색 중: 람쥐 어웨이
# ✅ 일반 결과: 람쥐 어웨이 → appid 2977620
#
# 🔍 검색 중: 엑스트라 인술 제10탄 「인주변화 칠미」
# ✅ 일반 결과: 엑스트라 인술 제10탄 「인주변화 칠미」 → appid 3020740
#
# 🔍 검색 중: mini royale
# ✅ 일반 결과: mini royale → appid 1657090
#
# 🔍 검색 중: galactic getaway: build a home for pets
# 🔍 필터링 결과에서 추출됨 → appid 2012390
#
# 🔍 검색 중: どきどきシャッターチャンス～恋のパズルを組み立てて♡～
# ✅ 일반 결과: どきどきシャッターチャンス～恋のパズルを組み立てて♡～ → appid 1973710
#
# 🔍 검색 중: 그림 가디언즈 서번트 오브 더 다크
# ✅ 일반 결과: 그림 가디언즈 서번트 오브 더 다크 → appid 3253630
#
# 🔍 검색 중: 프리미엄 아바타, 아바타 프레임 및 감정 표현
# ✅ 일반 결과: 프리미엄 아바타, 아바타 프레임 및 감정 표현 → appid 3241640
#
# 🔍 검색 중: 소녀의 움직이는 성
# ✅ 일반 결과: 소녀의 움직이는 성 → appid 2850220
#
# 🔍 검색 중: airlock arena: profit or perish
# 🔍 필터링 결과에서 추출됨 → appid 1111920
#
# 🔍 검색 중: zack in fight
# ✅ 일반 결과: zack in fight → appid 537110
#
# 🔍 검색 중: broad sword
# ✅ 일반 결과: broad sword → appid 720560
#
# 🔍 검색 중: unpossess: exorcism simulator
# 🔍 필터링 결과에서 추출됨 → appid 2976900
#
# 🔍 검색 중: 후즈후2.0
# ✅ 일반 결과: 후즈후2.0 → appid 3391260
#
# 🔍 검색 중: 기동전대 vs
# 🔍 필터링 결과에서 추출됨 → appid 2463800
#
# 🔍 검색 중: bleach 리버스 오브 소울즈
# ✅ 일반 결과: bleach 리버스 오브 소울즈 → appid 1689620
#
# 🔍 검색 중: sur5 quick start bundle
# ✅ 일반 결과: sur5 quick start bundle → appid 363890
#
# 🔍 검색 중: water-ring toss sim
# ✅ 일반 결과: water-ring toss sim → appid 1235733
#
# 🔍 검색 중: 8 인 너 plus (from 다함께 쿠키요미4)
# ✅ 일반 결과: 8 인 너 plus (from 다함께 쿠키요미4) → appid 3399580
#
# 🔍 검색 중: 怦然心动的瞬间-剧情&玩法 扩展包
# ✅ 일반 결과: 怦然心动的瞬间-剧情&玩法 扩展包 → appid None
#
# 🔍 검색 중: 百鬼图鉴-国风.挂机.卡牌.游戏
# ✅ 일반 결과: 百鬼图鉴-国风.挂机.卡牌.游戏 → appid 3241110
#
# 🔍 검색 중: 三国.群英重制版
# ✅ 일반 결과: 三国.群英重制版 → appid 3241110
#
# 🔍 검색 중: 내가 누군지 맞춰봐
# 🔍 필터링 결과에서 추출됨 → appid 2903710
#
# 🔍 검색 중: wwe 2k25 슈퍼차저
# 🔍 필터링 결과에서 추출됨 → appid 3401630
#
# 🔍 검색 중: wwe 2k25 슈퍼스타 메가 부스트
# 🔍 필터링 결과에서 추출됨 → appid 3482860
#
# 🔍 검색 중: wwe 2k25 myrise 부스트
# 🔍 필터링 결과에서 추출됨 → appid 3401640
#
# 🔍 검색 중: ferrous: digital edition
# ✅ 일반 결과: ferrous: digital edition → appid 3682540
#
# 🔍 검색 중: walkabout mini golf: mount olympus
# ✅ 일반 결과: walkabout mini golf: mount olympus → appid 3400950
#
# 🔍 검색 중: 체르노빌라이트 2: 금지구역
# 🔍 필터링 결과에서 추출됨 → appid 2075100
#
# 🔍 검색 중: 세라프 인 더 다크니스
# ✅ 일반 결과: 세라프 인 더 다크니스 → appid 2589920
#
# 🔍 검색 중: 괴물의 종말
# ✅ 일반 결과: 괴물의 종말 → appid 3461220
#
# 🔍 검색 중: undefined survivors -アンディファインド サバイバーズ-
# 🔍 필터링 결과에서 추출됨 → appid 2586430
#
# 🔍 검색 중: arcarg
# ✅ 일반 결과: arcarg → appid 3449460
#
# 🔍 검색 중: shop simulator: 다키마쿠라 전문몰
# ✅ 일반 결과: shop simulator: 다키마쿠라 전문몰 → appid 3361340
#
# 🔍 검색 중: 플랜트 포커
# ✅ 일반 결과: 플랜트 포커 → appid 3381760
#
# 🔍 검색 중: 우치하 사스케 스타터팩
# ✅ 일반 결과: 우치하 사스케 스타터팩 → appid 3244600
#
# 🔍 검색 중: 인술 특별 수련 제43탄 우치하 사스케(소년편 후기)
# ✅ 일반 결과: 인술 특별 수련 제43탄 우치하 사스케(소년편 후기) → appid 3020770
#
# 🔍 검색 중: 이브 온라인: 5단계 마스터리 패키지
# ✅ 일반 결과: 이브 온라인: 5단계 마스터리 패키지 → appid 3549090
#
# 🔍 검색 중: 이브 온라인: 4단계 마스터리 패키지
# ✅ 일반 결과: 이브 온라인: 4단계 마스터리 패키지 → appid 3549080
#
# 🔍 검색 중: 이브 온라인: 3단계 마스터리 패키지
# ✅ 일반 결과: 이브 온라인: 3단계 마스터리 패키지 → appid 3549070
#
# 🔍 검색 중: 이브 온라인: 2단계 마스터리 패키지
# ✅ 일반 결과: 이브 온라인: 2단계 마스터리 패키지 → appid 3549050
#
# 🔍 검색 중: 이브 온라인: 1단계 마스터리 패키지
# ✅ 일반 결과: 이브 온라인: 1단계 마스터리 패키지 → appid 3549040
#
# 🔍 검색 중: 중국 신화: 서유기
# 🔍 필터링 결과에서 추출됨 → appid 3433990
#
# 🔍 검색 중: jump 너 plus (from 다함께 쿠키요미4)
# ✅ 일반 결과: jump 너 plus (from 다함께 쿠키요미4) → appid 3399590
#
# 🔍 검색 중: 소대 돌격
# 🔍 필터링 결과에서 추출됨 → appid 3513740
#
# 🔍 검색 중: 99999량
# ✅ 일반 결과: 99999량 → appid 3501960
#
# 🔍 검색 중: 3on3 freestyle -beginner's starter kit
# ✅ 일반 결과: 3on3 freestyle -beginner's starter kit → appid 3530620
#
# 🔍 검색 중: 进化岛：jinhuadao
# ✅ 일반 결과: 进化岛：jinhuadao → appid 3241110
#
# 🔍 검색 중: 全城追缉3 三周年纪念车包
# 🔍 필터링 결과에서 추출됨 → appid 3431890
#
# 🔍 검색 중: 빛나는 인형
# ✅ 일반 결과: 빛나는 인형 → appid 3328720
#
# 🔍 검색 중: 너 게임 plus (from 다함께 쿠키요미4)
# ✅ 일반 결과: 너 게임 plus (from 다함께 쿠키요미4) → appid 3399570
#
# 🔍 검색 중: 异世界生存指南
# ✅ 일반 결과: 异世界生存指南 → appid 3241110
#
# 🔍 검색 중: 시드 마이어의 문명® vii 디럭스 에디션으로 업그레이드
# ✅ 일반 결과: 시드 마이어의 문명® vii 디럭스 에디션으로 업그레이드 → appid 3502600
#
# 🔍 검색 중: 시드 마이어의 문명® vii: 세계의 교차로 컬렉션
# ✅ 일반 결과: 시드 마이어의 문명® vii: 세계의 교차로 컬렉션 → appid 3004660
#
# 🔍 검색 중: door kickers 2: task force north
# ✅ 일반 결과: door kickers 2: task force north → appid 1239080
#
# 🔍 검색 중: pillow fight
# ✅ 일반 결과: pillow fight → appid 1816550
#
# 🔍 검색 중: 選んで！打って！！クイズ4択タイピング
# 🔍 필터링 결과에서 추출됨 → appid 3243420
#
# 🔍 검색 중: 冷战：前线 cold war frontline
# 🔍 필터링 결과에서 추출됨 → appid 3327950
#
# 🔍 검색 중: t1wre3: noname
# 🔍 필터링 결과에서 추출됨 → appid 3398150
#
# 🔍 검색 중: neon runners: craft & dash
# ✅ 일반 결과: neon runners: craft & dash → appid 2785860
#
# 🔍 검색 중: 돌연변이특공대 닌자거북이: 스플린터의 운명 케이시 존스와 폐차장 잼
# ✅ 일반 결과: 돌연변이특공대 닌자거북이: 스플린터의 운명 케이시 존스와 폐차장 잼 → appid 3316670
#
# 🔍 검색 중: spirit swap: lofi beats to match-3 to
# 🔍 필터링 결과에서 추출됨 → appid 1592170
#
# 🔍 검색 중: runncrush
# 🔍 필터링 결과에서 추출됨 → appid 1603470
#
# 🔍 검색 중: 엑스트라 인술 제9탄 「인주변화 삼미」
# ✅ 일반 결과: 엑스트라 인술 제9탄 「인주변화 삼미」 → appid 3020730
#
# 🔍 검색 중: skufs vs quadrobers 스쿠프 대 쿼드로버 대결
# ✅ 일반 결과: skufs vs quadrobers 스쿠프 대 쿼드로버 대결 → appid 3446850
#
# 🔍 검색 중: カードファイト!! ヴァンガード ディアデイズ2
# ...
#
# 🔍 검색 중: magicka: mega villain robes
# 🔍 필터링 결과에서 추출됨 → appid 73095
#
# 🔍 검색 중: magicka: aspiring musician robes
# 🔍 필터링 결과에서 추출됨 → appid 73096
#
# 🔍 검색 중: tom clancy's ghost recon: future soldier™
# ✅ 일반 결과: tom clancy's ghost recon: future soldier™ → appid 460930
#
# 🔍 검색 중: call of duty®: modern warfare® 3 (2011) collection 2
# ✅ 일반 결과: call of duty®: modern warfare® 3 (2011) collection 2 → appid None
#
# 🔍 검색 중: spellforce 2: faith in destiny
# ✅ 일반 결과: spellforce 2: faith in destiny → appid 1173820
#
# 🔍 검색 중: magicka: the other side of the coin
# ✅ 일반 결과: magicka: the other side of the coin → appid 1172620
#
# 🔍 검색 중: sins of a solar empire®: rebellion
# ✅ 일반 결과: sins of a solar empire®: rebellion → appid 228600
#
# 🔍 검색 중: stronghold 3 gold
# ✅ 일반 결과: stronghold 3 gold → appid 3751910
#
# 🔍 검색 중: iron front: digital war edition
# ✅ 일반 결과: iron front: digital war edition → appid 323190
#
# 🔍 검색 중: call of duty®: modern warfare® 3 (2011) collection 1
# ✅ 일반 결과: call of duty®: modern warfare® 3 (2011) collection 1 → appid None
#
# 🔍 검색 중: aliens: colonial marines collection
# ✅ 일반 결과: aliens: colonial marines collection → appid 1150440
#
# 🔍 검색 중: dungeon defenders: quest for the lost eternia shards part 3
# 🔍 필터링 결과에서 추출됨 → appid 204383
#
# 🔍 검색 중: all zombies must die!: scorepocalypse
# ✅ 일반 결과: all zombies must die!: scorepocalypse → appid 740080
#
# 🔍 검색 중: rayman® origins
# ✅ 일반 결과: rayman® origins → appid 3126630
#
# 🔍 검색 중: mutant storm: reloaded
# 🔍 필터링 결과에서 추출됨 → appid 110630
#
# 🔍 검색 중: take on helicopters: hinds
# 🔍 필터링 결과에서 추출됨 → appid 65733
#
# 🔍 검색 중: ship simulator extremes: ocean cruise ship
# ✅ 일반 결과: ship simulator extremes: ocean cruise ship → appid 3027860
#
# 🔍 검색 중: magicka: lonely island cruise
# 🔍 필터링 결과에서 추출됨 → appid 73039
#
# 🔍 검색 중: crusader kings ii: mongol faces
# ✅ 일반 결과: crusader kings ii: mongol faces → appid 3024040
#
# 🔍 검색 중: crusader kings ii: dynasty shields
# ✅ 일반 결과: crusader kings ii: dynasty shields → appid 3024040
#
# 🔍 검색 중: victoria ii: a house divided
# ✅ 일반 결과: victoria ii: a house divided → appid 420000
#
# 🔍 검색 중: ship simulator extremes: offshore vessel
# 🔍 필터링 결과에서 추출됨 → appid 48805
#
# 🔍 검색 중: delve deeper: gratis grottos
# ✅ 일반 결과: delve deeper: gratis grottos → appid 1644940
#
# 🔍 검색 중: dungeon defenders the great turkey hunt! mission & costumes
# 🔍 필터링 결과에서 추출됨 → appid 203700
#
# 🔍 검색 중: magicka: the stars are left
# 🔍 필터링 결과에서 추출됨 → appid 73058
#
# 🔍 검색 중: assassin's creed® revelations
# ✅ 일반 결과: assassin's creed® revelations → appid 201870
#
# 🔍 검색 중: ship simulator extremes: cargo vessel
# ✅ 일반 결과: ship simulator extremes: cargo vessel → appid 2445660
#
# 🔍 검색 중: anno 2070™
# ✅ 일반 결과: anno 2070™ → appid None
#
# 🔍 검색 중: sins of a solar empire: trinity®
# ✅ 일반 결과: sins of a solar empire: trinity® → appid 1575940
#
# 🔍 검색 중: sideway™ new york
# 🔍 필터링 결과에서 추출됨 → appid 200190
#
# 🔍 검색 중: dc universe™ online
# ✅ 일반 결과: dc universe™ online → appid 209000
#
# 🔍 검색 중: crazy machines 2: halloween
# ✅ 일반 결과: crazy machines 2: halloween → appid 294100
#
# 🔍 검색 중: payday™ the heist
# ✅ 일반 결과: payday™ the heist → appid 218620
#
# 🔍 검색 중: gratuitous space battles: the parasites
# ✅ 일반 결과: gratuitous space battles: the parasites → appid 2004680
#
# 🔍 검색 중: air conflicts: secret wars
# ✅ 일반 결과: air conflicts: secret wars → appid 1086940
#
# 🔍 검색 중: hoard: flame-broiled sandwich
# 🔍 필터링 결과에서 추출됨 → appid 63004
#
# 🔍 검색 중: red orchestra 2: heroes of stalingrad with rising storm
# ✅ 일반 결과: red orchestra 2: heroes of stalingrad with rising storm → appid None
#
# 🔍 검색 중: pride of nations: the franco-prussian war 1870
# 🔍 필터링 결과에서 추출됨 → appid 73194
#
# 🔍 검색 중: the kings' crusade: teutonic knights
# ✅ 일반 결과: the kings' crusade: teutonic knights → appid 1158310
#
# 🔍 검색 중: hoard: dynamite roll!
# 🔍 필터링 결과에서 추출됨 → appid 63003
#
# 🔍 검색 중: pride of nations: american civil war 1862
# 🔍 필터링 결과에서 추출됨 → appid 73193
#
# 🔍 검색 중: brink: agents of change
# ✅ 일반 결과: brink: agents of change → appid 3564740
#
# 🔍 검색 중: homefront: express 870 shotgun
# 🔍 필터링 결과에서 추출됨 → appid 55205
#
# 🔍 검색 중: pride of nations: spanish-american war 1898
# 🔍 필터링 결과에서 추출됨 → appid 73192
#
# 🔍 검색 중: dungeons and dragons: daggerdale
# ✅ 일반 결과: dungeons and dragons: daggerdale → appid 2958440
#
# 🔍 검색 중: beat hazard ultra
# ✅ 일반 결과: beat hazard ultra → appid 1581440
#
# 🔍 검색 중: trainz™ simulator 12
# 🔍 필터링 결과에서 추출됨 → appid 24670
#
# 🔍 검색 중: red faction®: armageddon™
# ✅ 일반 결과: red faction®: armageddon™ → appid 276190
#
# 🔍 검색 중: hearts of iron iii semper fi: dies irae götterdämmerung
# 🔍 필터링 결과에서 추출됨 → appid 42902
#
# 🔍 검색 중: mount & blade: with fire & sword
# ✅ 일반 결과: mount & blade: with fire & sword → appid 261550
#
# 🔍 검색 중: assassin’s creed® brotherhood
# ✅ 일반 결과: assassin’s creed® brotherhood → appid 48190
#
# 🔍 검색 중: atom zombie smasher
# 🔍 필터링 결과에서 추출됨 → appid 55040
#
# 🔍 검색 중: b.u.t.t.o.n. (brutally unfair tactics totally ok now)
# 🔍 필터링 결과에서 추출됨 → appid 92400
#
# 🔍 검색 중: dead space™ 2
# ✅ 일반 결과: dead space™ 2 → appid 548430
#
# 🔍 검색 중: 이브 온라인
# ✅ 일반 결과: 이브 온라인 → appid 8500
#
# 🔍 검색 중: blue toad murder files™: the mysteries of little riddle
# 🔍 필터링 결과에서 추출됨 → appid 90400
#
# 🔍 검색 중: gratuitous space battles: the nomads
# ✅ 일반 결과: gratuitous space battles: the nomads → appid 1884560
#
# 🔍 검색 중: archon classic
# 🔍 필터링 결과에서 추출됨 → appid 65400
#
# 🔍 검색 중: rhythm zone: deep ocean visualizer
# ✅ 일반 결과: rhythm zone: deep ocean visualizer → appid 3753690
#
# 🔍 검색 중: age of wonders ii: the wizard's throne
# ✅ 일반 결과: age of wonders ii: the wizard's throne → appid None
#
# 🔍 검색 중: age of wonders shadow magic
# ✅ 일반 결과: age of wonders shadow magic → appid 1669000
#
# 🔍 검색 중: guild wars: eye of the north®
# ✅ 일반 결과: guild wars: eye of the north® → appid 29700
#
# 🔍 검색 중: air forte
# ✅ 일반 결과: air forte → appid 3174120
#
# 🔍 검색 중: dead rising® 2
# ✅ 일반 결과: dead rising® 2 → appid 45740
#
# 🔍 검색 중: serious sam hd: gold edition
# 🔍 필터링 결과에서 추출됨 → appid 901553
#
# 🔍 검색 중: kane & lynch 2: the doggie bag
# 🔍 필터링 결과에서 추출됨 → appid 28010
#
# 🔍 검색 중: victoria i complete
# ✅ 일반 결과: victoria i complete → appid None
#
# 🔍 검색 중: madballs holiday skin rollup
# ✅ 일반 결과: madballs holiday skin rollup → appid 25763
#
# 🔍 검색 중: madballs scorched evolution skin rollup
# ✅ 일반 결과: madballs scorched evolution skin rollup → appid 25763
#
# 🔍 검색 중: madballs bdi evolution skin rollup
# ✅ 일반 결과: madballs bdi evolution skin rollup → appid 25762
#
# 🔍 검색 중: madballs b*d*i clan skins
# ✅ 일반 결과: madballs b*d*i clan skins → appid 25760
#
# 🔍 검색 중: madballs scorched clan skins
# ✅ 일반 결과: madballs scorched clan skins → appid 25761
#
# 🔍 검색 중: theatre of war 2: kursk 1943
# ✅ 일반 결과: theatre of war 2: kursk 1943 → appid 686810
#
# 🔍 검색 중: singularity™
# ✅ 일반 결과: singularity™ → appid 977400
#
# 🔍 검색 중: duels of the planeswalkers gold game bundle
# ✅ 일반 결과: duels of the planeswalkers gold game bundle → appid None
#
# 🔍 검색 중: hearts of iron iii: semper fi
# 🔍 필터링 결과에서 추출됨 → appid 42900
#
# 🔍 검색 중: sword of the stars: complete collection
# ✅ 일반 결과: sword of the stars: complete collection → appid 2526380
#
# 🔍 검색 중: majesty 2: kingmaker
# 🔍 필터링 결과에서 추출됨 → appid 42881
#
# 🔍 검색 중: gratuitous space battles: the swarm
# ✅ 일반 결과: gratuitous space battles: the swarm → appid 2183900
#
# 🔍 검색 중: tom clancy's splinter cell conviction™
# ✅ 일반 결과: tom clancy's splinter cell conviction™ → appid None
#
# 🔍 검색 중: hidden expedition: titanic
# ✅ 일반 결과: hidden expedition: titanic → appid 2306620
#
# 🔍 검색 중: wings of luftwaffe add-on
# 🔍 필터링 결과에서 추출됨 → appid 45302
#
# 🔍 검색 중: lead and gold: gangs of the wild west
# ✅ 일반 결과: lead and gold: gangs of the wild west → appid 610370
#
# 🔍 검색 중: gratuitous space battles: the order
# ✅ 일반 결과: gratuitous space battles: the order → appid 1594320
#
# 🔍 검색 중: silent hunter 5®: battle of the atlantic
# ✅ 일반 결과: silent hunter 5®: battle of the atlantic → appid 1272010
#
# 🔍 검색 중: sonic & sega all-stars racing
# ✅ 일반 결과: sonic & sega all-stars racing → appid 2486820
#
# 🔍 검색 중: arsenal of democracy: a hearts of iron game
# ✅ 일반 결과: arsenal of democracy: a hearts of iron game → appid 2781620
#
# 🔍 검색 중: aliens vs. predator™
# ✅ 일반 결과: aliens vs. predator™ → appid 2352050
#
# 🔍 검색 중: pirates, vikings, and knights ii
# ✅ 일반 결과: pirates, vikings, and knights ii → appid 17570
#
# 🔍 검색 중: lost planet: extreme condition colonies edition
# 🔍 필터링 결과에서 추출됨 → appid 45720
#
# 🔍 검색 중: bioshock® 2
# ✅ 일반 결과: bioshock® 2 → appid 214932
#
# 🔍 검색 중: gratuitous space battles: the tribe
# ✅ 일반 결과: gratuitous space battles: the tribe → appid 874390
#
# 🔍 검색 중: crash time 3
# ✅ 일반 결과: crash time 3 → appid 294100
#
# 🔍 검색 중: for the glory: a europa universalis game
# ✅ 일반 결과: for the glory: a europa universalis game → appid 3450310
#
# 🔍 검색 중: rush for berlin gold
# ✅ 일반 결과: rush for berlin gold → appid None
#
# 🔍 검색 중: the stronghold collection
# ✅ 일반 결과: the stronghold collection → appid 1335830
#
# 🔍 검색 중: joint operations: combined arms gold
# ✅ 일반 결과: joint operations: combined arms gold → appid 1604270
#
# 🔍 검색 중: madballs in babo:invasion
# ✅ 일반 결과: madballs in babo:invasion → appid 25700
#
# 🔍 검색 중: red faction guerrilla steam edition
# ✅ 일반 결과: red faction guerrilla steam edition → appid 2482850
#
# 🔍 검색 중: biohazard 5
# ✅ 일반 결과: biohazard 5 → appid None
#
# 🔍 검색 중: xiii century – gold edition
# ✅ 일반 결과: xiii century – gold edition → appid 1080550
#
# 🔍 검색 중: kingpin — life of crime
# ✅ 일반 결과: kingpin — life of crime → appid None
#
# 🔍 검색 중: fallout tactics: brotherhood of steel
# ✅ 일반 결과: fallout tactics: brotherhood of steel → appid None
#
# 🔍 검색 중: timeshift™
# ✅ 일반 결과: timeshift™ → appid None
#
# 🔍 검색 중: supreme ruler 2020 gold
# 🔍 필터링 결과에서 추출됨 → appid 25910
#
# 🔍 검색 중: star wars™ republic commando™
# ✅ 일반 결과: star wars™ republic commando™ → appid 3271180
#
# 🔍 검색 중: lego® indiana jones™: the original adventures
# 🔍 필터링 결과에서 추출됨 → appid 32330
#
# 🔍 검색 중: star wars™ battlefront ii (classic, 2005)
# 🔍 필터링 결과에서 추출됨 → appid 6060
#
# 🔍 검색 중: thrillville®: off the rails™
# 🔍 필터링 결과에서 추출됨 → appid 6080
#
# 🔍 검색 중: delta force xtreme 2
# ✅ 일반 결과: delta force xtreme 2 → appid 2782610
#
# 🔍 검색 중: delta force land warrior
# ✅ 일반 결과: delta force land warrior → appid 2507950
#
# 🔍 검색 중: delta force — black hawk down: team sabre
# ✅ 일반 결과: delta force — black hawk down: team sabre → appid 2507950
#
# 🔍 검색 중: battlestations pacific
# 🔍 필터링 결과에서 추출됨 → appid 8170
#
# 🔍 검색 중: men of war™
# ✅ 일반 결과: men of war™ → appid 1128860
#
# 🔍 검색 중: two worlds epic edition
# ✅ 일반 결과: two worlds epic edition → appid 2542120
#
# 🔍 검색 중: guild wars factions®
# ✅ 일반 결과: guild wars factions® → appid 3564740
#
# 🔍 검색 중: guild wars nightfall®
# 🔍 필터링 결과에서 추출됨 → appid 29580
#
# 🔍 검색 중: guild wars® game of the year edition
# ✅ 일반 결과: guild wars® game of the year edition → appid 2778580
#
# 🔍 검색 중: guild wars® trilogy
# 🔍 필터링 결과에서 추출됨 → appid 29570
#
# 🔍 검색 중: judge dredd: dredd vs. death
# ✅ 일반 결과: judge dredd: dredd vs. death → appid None
#
# 🔍 검색 중: europa universalis iii complete
# ✅ 일반 결과: europa universalis iii complete → appid 602960
#
# 🔍 검색 중: hearts of iron 2 complete
# ✅ 일반 결과: hearts of iron 2 complete → appid 294100
#
# 🔍 검색 중: far cry® 2
# ✅ 일반 결과: far cry® 2 → appid 2369456
#
# 🔍 검색 중: pacific storm allies
# ✅ 일반 결과: pacific storm allies → appid None
#
# 🔍 검색 중: sprint cars road to knoxville
# ✅ 일반 결과: sprint cars road to knoxville → appid 1038250
#
# 🔍 검색 중: empires mod
# ✅ 일반 결과: empires mod → appid 427520
#
# 🔍 검색 중: tom clancy's ghost recon® desert siege™
# ✅ 일반 결과: tom clancy's ghost recon® desert siege™ → appid None
#
# 🔍 검색 중: tom clancy's ghost recon®
# ✅ 일반 결과: tom clancy's ghost recon® → appid 460930
#
# 🔍 검색 중: silent hunter®: wolves of the pacific u-boat missions
# 🔍 필터링 결과에서 추출됨 → appid 15240
#
# 🔍 검색 중: silent hunter®: wolves of the pacific
# 🔍 필터링 결과에서 추출됨 → appid 15200
#
# 🔍 검색 중: silent hunter® iii
# ✅ 일반 결과: silent hunter® iii → appid None
#
# 🔍 검색 중: tom clancy's rainbow six lockdown™
# ✅ 일반 결과: tom clancy's rainbow six lockdown™ → appid 359550
#
# 🔍 검색 중: tom clancy's rainbow six® vegas
# ✅ 일반 결과: tom clancy's rainbow six® vegas → appid 359550
#
# 🔍 검색 중: frontlines™: fuel of war™
# ✅ 일반 결과: frontlines™: fuel of war™ → appid None
#
# 🔍 검색 중: the club™
# ✅ 일반 결과: the club™ → appid 1665460
#
# 🔍 검색 중: puzzlequest: challenge of the warlords
# 🔍 필터링 결과에서 추출됨 → appid 12500
#
# 🔍 검색 중: kane and lynch: dead men™
# 🔍 필터링 결과에서 추출됨 → appid 8080
#
# 🔍 검색 중: shadowgrounds survivor
# ✅ 일반 결과: shadowgrounds survivor → appid None
#
# 🔍 검색 중: medieval ii: total war™ kingdoms
# ✅ 일반 결과: medieval ii: total war™ kingdoms → appid 261550
#
# 🔍 검색 중: lost planet™: extreme condition
# ✅ 일반 결과: lost planet™: extreme condition → appid 6510
#
# 🔍 검색 중: sid meier's civilization® iv
# ✅ 일반 결과: sid meier's civilization® iv → appid 1295660
#
# 🔍 검색 중: sid meier's civilization® iii complete
# ✅ 일반 결과: sid meier's civilization® iii complete → appid None
#
# 🔍 검색 중: call of duty® (2003)
# ✅ 일반 결과: call of duty® (2003) → appid None
#
# 🔍 검색 중: the ship: murder party
# ✅ 일반 결과: the ship: murder party → appid 638070
#
# 🔍 검색 중: climbing chaos: much earlier access
# ✅ 일반 결과: climbing chaos: much earlier access → appid 3279760
#
# 🔍 검색 중: 漂流到岛
# ✅ 일반 결과: 漂流到岛 → appid 3241110
#
# 🔍 검색 중: fourth age: idle rpg
# ✅ 일반 결과: fourth age: idle rpg → appid 3241110
#
# 🔍 검색 중: touhou tenshiin ~ celestial examination hall
# 🔍 필터링 결과에서 추출됨 → appid 3566860
#
# 🔍 검색 중: 荒野国度 legends of the wild
# ✅ 일반 결과: 荒野国度 legends of the wild → appid None
#
# 🔍 검색 중: druid's crown
# ✅ 일반 결과: druid's crown → appid None
#
# 🔍 검색 중: kamioza (ch1 azaria)
# 🔍 필터링 결과에서 추출됨 → appid 3522380
#
# 🔍 검색 중: cof
# 🔍 필터링 결과에서 추출됨 → appid 3635070
#
# 🔍 검색 중: erascape : escape duo
# ✅ 일반 결과: erascape : escape duo → appid 3636680
#
# 🔍 검색 중: 코드명:황혼
# ✅ 일반 결과: 코드명:황혼 → appid 3642420
#
# 🔍 검색 중: liv: nordic survival
# 🔍 필터링 결과에서 추출됨 → appid 3642500
#
# 🔍 검색 중: monsters and me 🧟‍♂️🤷‍♂️
# ❌ appid 추출 실패
#
# 🔍 검색 중: 360헥사월드 -메타버스 게임 크리에이터 아바타 게임
# ✅ 일반 결과: 360헥사월드 -메타버스 게임 크리에이터 아바타 게임 → appid 3308580
#
# 🔍 검색 중: 5th dimension
# ✅ 일반 결과: 5th dimension → appid 1172650
#
# 🔍 검색 중: disaster party!
# ✅ 일반 결과: disaster party! → appid 2064650
#
# 🔍 검색 중: hauntibles
# 🔍 필터링 결과에서 추출됨 → appid 3591270
#
# 🔍 검색 중: evolve monsters infinite
# ✅ 일반 결과: evolve monsters infinite → appid 281990
#
# 🔍 검색 중: apes at sea
# ✅ 일반 결과: apes at sea → appid 389510
#
# 🔍 검색 중: convicts collection
# ✅ 일반 결과: convicts collection → appid 718590
#
# 🔍 검색 중: arbo: arena tactics
# 🔍 필터링 결과에서 추출됨 → appid 2914810
#
# 🔍 검색 중: protagonist complex one
# ✅ 일반 결과: protagonist complex one → appid 3012130
#
# 🔍 검색 중: salarybot shuffle
# 🔍 필터링 결과에서 추출됨 → appid 3067310
#
# 🔍 검색 중: sea raiders : stream chat games
# 🔍 필터링 결과에서 추출됨 → appid 2631810
#
# 🔍 검색 중: 아스트로블록
# ✅ 일반 결과: 아스트로블록 → appid 2747930
#
# 🔍 검색 중: dwarfs delight
# ✅ 일반 결과: dwarfs delight → appid 2964020
#
# 🔍 검색 중: 몬스터 프로젝트
# ✅ 일반 결과: 몬스터 프로젝트 → appid 2736450
#
# 🔍 검색 중: the snake kingdom of gennibar-six
# ✅ 일반 결과: the snake kingdom of gennibar-six → appid 1399400
#
# 🔍 검색 중: biochaos
# 🔍 필터링 결과에서 추출됨 → appid 2712350
#
# 🔍 검색 중: youra the game
# 🔍 필터링 결과에서 추출됨 → appid 2724180
#
# 🔍 검색 중: obsolete souls™ episode 0: operation haiti
# 🔍 필터링 결과에서 추출됨 → appid 2845760
#
# 🔍 검색 중: airsoft battle royale
# 🔍 필터링 결과에서 추출됨 → appid 3024220
#
# 🔍 검색 중: mayalok alpha v0.1.7
# 🔍 필터링 결과에서 추출됨 → appid 3026030
#
# 🔍 검색 중: 에어&후크
# ✅ 일반 결과: 에어&후크 → appid 3012760
#
# 🔍 검색 중: black ember
# ✅ 일반 결과: black ember → appid 2706010
#
# 🔍 검색 중: 식민지 고양이: 위기의 한가운데에서
# 🔍 필터링 결과에서 추출됨 → appid 3181260
#
# 🔍 검색 중: 雪花斗兽棋
# 🔍 필터링 결과에서 추출됨 → appid 3662240
#
# 🔍 검색 중: 打楼板 floorbreaker
# 🔍 필터링 결과에서 추출됨 → appid 3672250
#
# 🔍 검색 중: fox & finch, 1, 2, jellies!
# ✅ 일반 결과: fox & finch, 1, 2, jellies! → appid 997360
#
# 🔍 검색 중: d.e.l.i.v.e.r.e.r.s.
# ✅ 일반 결과: d.e.l.i.v.e.r.e.r.s. → appid 3684080
#
# 🔍 검색 중: oops! my king!
# ✅ 일반 결과: oops! my king! → appid 3061000
#
# 🔍 검색 중: pitfight
# 🔍 필터링 결과에서 추출됨 → appid 3093470
#
# 🔍 검색 중: twin flames
# ✅ 일반 결과: twin flames → appid 3084560
#
# 🔍 검색 중: chained 2 violence
# ✅ 일반 결과: chained 2 violence → appid 2669440
#
# 🔍 검색 중: 이상한 블록36
# ✅ 일반 결과: 이상한 블록36 → appid 3260310
#
# 🔍 검색 중: big 2 × dodgeball dojo®
# ✅ 일반 결과: big 2 × dodgeball dojo® → appid 3266210
#
# 🔍 검색 중: parts unknown: the last fight
# ✅ 일반 결과: parts unknown: the last fight → appid 648800
#
# 🔍 검색 중: 龙魂无限斗 dragonspiritsinfight
# ✅ 일반 결과: 龙魂无限斗 dragonspiritsinfight → appid 3241110
#
# 🔍 검색 중: nefarius: the last wizard
# ✅ 일반 결과: nefarius: the last wizard → appid 1555110
#
# 🔍 검색 중: bestgame
# 🔍 필터링 결과에서 추출됨 → appid 3709270
#
# 🔍 검색 중: crabs and rats
# ✅ 일반 결과: crabs and rats → appid 1723880
#
# 🔍 검색 중: adventure jam
# ✅ 일반 결과: adventure jam → appid 1782170
#
# 🔍 검색 중: the train arrived!
# ✅ 일반 결과: the train arrived! → appid 346110
#
# 🔍 검색 중: dispatch control
# ✅ 일반 결과: dispatch control → appid 3010460
#
# 🔍 검색 중: watertrix online
# 🔍 필터링 결과에서 추출됨 → appid 3172540
#
# 📁 저장 완료: mapped_appids_final.csv

# %%
# appid 목록 (영문 제목 기준)
appid_df = pd.read_csv("02-2. mapped_appids_final.csv")

# 아까 1차맵핑한 데이터
multi_df = pd.read_csv("02-1. merged_steam_data.csv")  # 컬럼: title_eng, genre 등

# %%
import pandas as pd

# appid가 NaN인 행만 추출
no_appid_df = multi_df[multi_df['appid'].isnull()].copy()

# %%
# appid_df에서 게임명 기준으로 병합
mapped = pd.merge(
    no_appid_df,
    appid_df[['게임명', 'appid']],
    on='게임명',
    how='left',
    suffixes=('', '_new')
)

# 기존 appid가 NaN인 경우에만 새 appid로 대체
mapped['appid'] = mapped['appid_new'].combine_first(mapped['appid'])
mapped = mapped.drop(columns=['appid_new'])

# 기존 appid가 있는 행과 합치기
with_appid = multi_df[multi_df['appid'].notnull()]
final_df = pd.concat([with_appid, mapped], ignore_index=True)

final_df
# 필요시 저장
# final_df.to_csv("multi_df_appid_merged.csv", index=False, encoding="utf-8-sig")
# Out:
#                               게임명           출시일  \
# 0           football manager 2024  2023년 11월 7일
# 1                          ride 5  2023년 8월 24일
# 2                    broken arrow  2025년 6월 20일
# 3            guilty gear -strive-  2021년 6월 11일
# 4      magic: the gathering arena  2023년 5월 24일
# ...                           ...           ...
# 24590              crabs and rats         출시 예정
# 24591               adventure jam         출시 예정
# 24592          the train arrived!         발표 예정
# 24593            dispatch control         발표 예정
# 24594            watertrix online         출시 예정
#
#                                            장르       OS           평가점수  \
# 0                  시뮬레이션 | 스포츠 | 경영 | 축구 | 전략  Windows  평가 점수: 매우 긍정적
# 1            레이싱 | 시뮬레이션 | 오토바이 | 스포츠 | 분할 화면  Windows  평가 점수: 매우 긍정적
# 2           전략 | 전쟁 게임 | 현대 | 실시간 전략 | 실시간 전술  Windows     평가 점수: 복합적
# 3        격투 | 2D 격투 | 웅장한 사운드트랙 | 애니메이션 | PvP  Windows  평가 점수: 매우 긍정적
# 4      전략 | 카드 게임 | 트레이딩 카드 게임 | 무료 플레이 | 덱빌딩  Windows     평가 점수: 복합적
# ...                                       ...      ...            ...
# 24590          액션 | 캐주얼 | 아케이드 | 플랫폼 | 2D 플랫폼  Windows            NaN
# 24591       어드벤처 | 액션 | RPG | 2D 격투 | 액션 어드벤처  Windows            NaN
# 24592               어드벤처 | RPG | 액션 | 기차 | 퍼즐  Windows            NaN
# 24593         시뮬레이션 | 전략 | 캐주얼 | 실시간 전략 | 대전략  Windows            NaN
# 24594    시뮬레이션 | 캐주얼 | e스포츠 | 2D 플랫폼 | 퍼즐 플랫폼  Windows            NaN
#
#              사용자 평가 수  DLC여부      appid                        name
# 0      사용자 평가 14,753개      0  2252570.0       football manager 2024
# 1       사용자 평가 2,092개      0  1650010.0                      ride 5
# 2      사용자 평가 12,836개      0  1604270.0                broken arrow
# 3      사용자 평가 43,066개      0  1384160.0        guilty gear -strive-
# 4      사용자 평가 21,004개      0  2141910.0  magic: the gathering arena
# ...               ...    ...        ...                         ...
# 24590             NaN      0    1723880                         NaN
# 24591             NaN      0    1782170                         NaN
# 24592             NaN      0     346110                         NaN
# 24593             NaN      0    3010460                         NaN
# 24594             NaN      0    3172540                         NaN
#
# [24595 rows x 9 columns]

# %% [markdown]
# ### 4. 최종파일 정제

# %%
final_df = final_df.drop(columns=['name'])

# %%
final_df = final_df[['appid', '게임명', '출시일', '장르', 'OS','DLC여부', '평가점수', '사용자 평가 수']]

# %%
final_df = final_df[~final_df['appid'].astype(str).str.contains(',')]

# %%
# 쉼표로 분리해서 첫 번째 값만 남기고 숫자로 변환
final_df['appid'] = final_df['appid'].astype(str).str.split(',').str[0]
final_df['appid'] = pd.to_numeric(final_df['appid'], errors='coerce').astype('Int64')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24592 entries, 0 to 24594
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   appid     24332 non-null  Int64
#  1   게임명       24555 non-null  object
#  2   출시일       24450 non-null  object
#  3   장르        24591 non-null  object
#  4   OS        24590 non-null  object
#  5   DLC여부     24592 non-null  int64
#  6   평가점수      13540 non-null  object
#  7   사용자 평가 수  13540 non-null  object
# dtypes: Int64(1), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
final_df = final_df[~final_df["게임명"].str.contains(r"에디션|번들|코스튬|키트", flags=re.IGNORECASE, na=False)]

# %%
final_df = final_df[~final_df["게임명"].str.contains(r"マーダーミステリーｊ|バトルスピリッツ クロスオーバー|ビビッター　追加ミニゲーム|ダンジョン人狼", flags=re.IGNORECASE, na=False)]

# %%
final_df[final_df['appid'].isnull()]
# Out:
#        appid                                      게임명            출시일  \
# 21410   <NA>                        oddsparks: 자동화 모험   2025년 5월 28일
# 21417   <NA>               goddess of fate: waifu rpg    2025년 4월 1일
# 21425   <NA>                            용과 같이0 맹세의 장소    2018년 8월 1일
# 21453   <NA>           슈퍼 테크노스 월드 ~열혈 & 아케이드 클래식 컬렉션~   2025년 4월 24일
# 21485   <NA>  call of duty® 4: modern warfare® (2007)  2007년 11월 13일
# ...      ...                                      ...            ...
# 24538   <NA>   sid meier's civilization® iii complete  2006년 10월 25일
# 24539   <NA>                     call of duty® (2003)  2006년 10월 14일
# 24545   <NA>                 荒野国度 legends of the wild          출시 예정
# 24546   <NA>                            druid's crown          발표 예정
# 24552   <NA>                 monsters and me 🧟‍♂️🤷‍♂️          출시 예정
#
#                                                 장르       OS  DLC여부  \
# 21410             건설 | 싱글 플레이어 | 협동 | 절차적 생성 | 자동화  Windows      0
# 21417              전략 | RPG | 애니메이션 | JRPG | 턴제 전략  Windows      0
# 21425          풍부한 스토리 | 액션 | 비뎀업 | 웅장한 사운드트랙 | 범죄  Windows      0
# 21453           액션 | 스포츠 | 아케이드 | 액션 어드벤처 | 2D 플랫폼  Windows      0
# 21485          1인칭 슈팅 | 액션 | 멀티플레이어 | 슈팅 | 싱글 플레이어  Windows      0
# ...                                            ...      ...    ...
# 24538                   전략 | 턴제 전략 | 턴제 | 클래식 | 4X  Windows      0
# 24539       1인칭 슈팅 | 제2차 세계 대전 | 액션 | 클래식 | 멀티플레이어  Windows      0
# 24545                전략 | 4X | 판타지 | 턴제 전략 | 전쟁 게임  Windows      0
# 24546           어드벤처 | RPG | 액션 RPG | 아케이드 | 탄막 슈팅  Windows      0
# 24552  탑다운 슈팅 | 로그라이트 | 액션 로그라이크 | 트윈 스틱 슈팅 | 아케이드  Windows      0
#
#                    평가점수        사용자 평가 수
# 21410     평가 점수: 매우 긍정적   사용자 평가 1,536개
# 21417    평가 점수: 대체로 긍정적     사용자 평가 237개
# 21425  평가 점수: 압도적으로 긍정적  사용자 평가 59,046개
# 21453    평가 점수: 대체로 긍정적      사용자 평가 18개
# 21485     평가 점수: 매우 긍정적  사용자 평가 20,417개
# ...                 ...             ...
# 24538     평가 점수: 매우 긍정적   사용자 평가 5,280개
# 24539     평가 점수: 매우 긍정적   사용자 평가 6,518개
# 24545               NaN             NaN
# 24546               NaN             NaN
# 24552               NaN             NaN
#
# [163 rows x 8 columns]

# %% [markdown]
# ### 4. 누락된 appid(163행) 수동으로 수집

# %%
final_df.to_csv("01-2. steam_data_fianl.csv", index=False, encoding='utf-8-sig')

# %%
final_df = pd.read_csv("01-2. steam_data_final.csv", encoding= 'cp949')
final_df
# Out:
#          appid                         게임명            출시일  \
# 0      2252570       football manager 2024  2023년 11월 07일
# 1      1650010                      ride 5  2023년 08월 24일
# 2      1604270                broken arrow  2025년 06월 20일
# 3      1384160        guilty gear -strive-  2021년 06월 11일
# 4      2141910  magic: the gathering arena  2023년 05월 24일
# ...        ...                         ...            ...
# 24373  1723880              crabs and rats          출시 예정
# 24374  1782170               adventure jam          출시 예정
# 24375   346110          the train arrived!          발표 예정
# 24376  3010460            dispatch control          발표 예정
# 24377  3172540            watertrix online          출시 예정
#
#                                            장르       OS  DLC여부           평가점수  \
# 0                  시뮬레이션 | 스포츠 | 경영 | 축구 | 전략  Windows      0  평가 점수: 매우 긍정적
# 1            레이싱 | 시뮬레이션 | 오토바이 | 스포츠 | 분할 화면  Windows      0  평가 점수: 매우 긍정적
# 2           전략 | 전쟁 게임 | 현대 | 실시간 전략 | 실시간 전술  Windows      0     평가 점수: 복합적
# 3        격투 | 2D 격투 | 웅장한 사운드트랙 | 애니메이션 | PvP  Windows      0  평가 점수: 매우 긍정적
# 4      전략 | 카드 게임 | 트레이딩 카드 게임 | 무료 플레이 | 덱빌딩  Windows      0     평가 점수: 복합적
# ...                                       ...      ...    ...            ...
# 24373          액션 | 캐주얼 | 아케이드 | 플랫폼 | 2D 플랫폼  Windows      0            NaN
# 24374       어드벤처 | 액션 | RPG | 2D 격투 | 액션 어드벤처  Windows      0            NaN
# 24375               어드벤처 | RPG | 액션 | 기차 | 퍼즐  Windows      0            NaN
# 24376         시뮬레이션 | 전략 | 캐주얼 | 실시간 전략 | 대전략  Windows      0            NaN
# 24377    시뮬레이션 | 캐주얼 | e스포츠 | 2D 플랫폼 | 퍼즐 플랫폼  Windows      0            NaN
#
#              사용자 평가 수
# 0      사용자 평가 14,753개
# 1       사용자 평가 2,092개
# 2      사용자 평가 12,836개
# 3      사용자 평가 43,066개
# 4      사용자 평가 21,004개
# ...               ...
# 24373             NaN
# 24374             NaN
# 24375             NaN
# 24376             NaN
# 24377             NaN
#
# [24378 rows x 8 columns]

# %% [markdown]
# ### 5. 재정제

# %%
final_df = final_df[~final_df["게임명"].str.contains(r"인술 특별 수련 시리즈|soundtrack|\s mode|\s tracks| – |探灵笔记·古墓地宫系列|bundle|의상|edition| — | ~ |패키지", flags=re.IGNORECASE, na=False)]

# %%
final_df[final_df["게임명"].str.contains(r"beat saber", flags=re.IGNORECASE, na=False)]
# Out:
#          appid                                                게임명  \
# 129     620980                                         beat saber
# 23014  1725507  beat saber: skrillex & wolfgang gartner ? 'the...
# 23015  1725506  beat saber: skrillex ? 'scary monsters and nic...
# 23016  1725502  beat saber: skrillex, justin bieber & don toli...
# 23017  1725501  beat saber: skrillex, starrah & four tet ? 'bu...
# 23066  1636342       beat saber: the pussycat dolls ? 'don't cha'
# 23067  1636343  beat saber: lmfao ft. lauren bennett, goonrock...
# 23068  1636345                     beat saber: maroon 5 ? 'sugar'
# 23069  1636346  beat saber: gwen stefani ? 'the sweet escape f...
#
#                  출시일                            장르       OS  DLC여부  \
# 129    2019년 05월 22일  VR | 리듬 | 음악 | 모드 가능 | 빠른 진행  Windows      0
# 23014  2021년 08월 31일                            인디  Windows      0
# 23015  2021년 08월 31일                            인디  Windows      0
# 23016  2021년 08월 31일                            인디  Windows      0
# 23017  2021년 08월 31일                            인디  Windows      0
# 23066  2021년 05월 27일                            인디  Windows      0
# 23067  2021년 05월 27일                            인디  Windows      0
# 23068  2021년 05월 27일                            인디  Windows      0
# 23069  2021년 05월 27일                            인디  Windows      0
#
#                    평가점수        사용자 평가 수
# 129    평가 점수: 압도적으로 긍정적  사용자 평가 68,387개
# 23014               NaN             NaN
# 23015               NaN             NaN
# 23016               NaN             NaN
# 23017               NaN             NaN
# 23066               NaN             NaN
# 23067        평가 점수: 긍정적      사용자 평가 31개
# 23068               NaN             NaN
# 23069               NaN             NaN

# %%
drop_idx = [23014,23015,23016,23017,23066,23067,23068,23069]
final_df = final_df.drop(index=drop_idx)
final_df = final_df.reset_index(drop=True)

# %%
final_df = final_df[final_df["장르"].str.contains(r"무료 플레이|MOBA|히어로 슈팅|1인칭 슈팅|3인칭 슈팅|멀티플레이어|1인칭|팀 기반|3인칭|PvP|경쟁|슈팅|액션|협동|공상과학|PvE|온라인 협동|시네마틱|깊은 세계관|캐주얼", flags=re.IGNORECASE, na=False)]

# %%
final_df.to_csv("02-3. steam_data_real.csv", index=False, encoding='utf-8-sig')
